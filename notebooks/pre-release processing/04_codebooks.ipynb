# %% [markdown]
# # Creating the Code Books
#
# This notebook creates the codebooks for future researchers. [Codebooks](https://www.icpsr.umich.edu/web/ICPSR/cms/1983) often accompany social science datasets. We make a big latex table at the end to convert the dataset info to a PDF.

# %%
# Setup
import pandas as pd
import numpy as np
from src.utils.helper_funcs import find_project_root
from src.utils.data_loader import load_data, unnest_columns

# Set up paths
PROJECT_ROOT = find_project_root()

# Load data
data_dict = load_data()

# Load the raw qualtrics survey mapping
survey_mapping = pd.read_json(
    PROJECT_ROOT / "data" / "storage" / "mappings" / "survey_question_mapping.json"
)

header_usecases = pd.read_csv(
    PROJECT_ROOT / "data" / "storage" / "mappings" / "header_usecases_mapping.csv"
)

header_prefs = pd.read_csv(
    PROJECT_ROOT / "data" / "storage" / "mappings" / "header_prefs_mapping.csv"
)


# Create a dictionary
survey_mapping_dict = survey_mapping.to_dict()

# %%
display(header_usecases.head(4))

display(header_prefs.head(4))
# Out:
#                 header survey_numeric  \
# 0        shared_opener            NaN
# 1  homework_assistance              1
# 2             research              2
# 3   source_suggestions              3
#
#                                          survey_text
# 0  Which of the following scenarios best describe...
# 1  **Homework Assistance**: Getting help with sch...
# 2  **Research**: Fact-checking or gaining overvie...
# 3  **Source Suggestions**: Creating or finding bi...
#           header survey_numeric  \
# 0  slider_values            NaN
# 1  shared_opener            NaN
# 2         values              1
# 3     creativity             10
#
#                                          survey_text  \
# 0                Strongly Disagree - Strongly Agree
# 1    It is important that an AI language model... -
# 2     ...reflects my values or cultural perspectives
# 3  ...produces responses that are creative and in...
#
#                 conversations_performance_factors  \
# 0    Performed very poorly - Performed very well
# 1                            <b>This response</b>
# 2  ...reflected my values or cultural perspective
# 3                   ...was creative and inspiring
#
#                         conversations_choice_factors
# 0                  Very unimportant - Very important
# 1                       <b>I chose this response</b>
# 2  ...because it reflected my values or cultural ...
# 3           ...because it was creative and inspiring

# %% [markdown]
# ## General Functions

# %%
def return_codebook_entry(
    ENTRIES,
    df,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
    show_values=True,
):
    if "dict" in variable_type:
        num_missing, num_unique = "-", "-"
    else:
        # Get num missing
        num_missing = df[variable_name].isna().sum()
        # Get num unique
        num_unique = df[variable_name].nunique()

    # Get values depending on variable type
    if show_values:
        if variable_type in ["int", "float"]:
            values_dict = {}
            for stat in ["mean", "std", "min", "max"]:
                values_dict[stat] = np.round(
                    df[variable_name].describe().to_dict()[stat], 1
                )
        elif variable_type == "string":
            values_dict = {}
            for stat in ["mean", "std", "min", "max"]:
                values_dict[f"{stat} chars"] = np.round(
                    df[variable_name].str.len().describe().to_dict()[stat], 1
                )
        elif variable_type in ["categorical", "binary"]:
            values_dict = df[variable_name].value_counts(dropna=False).to_dict()
        elif variable_type == "datetime":
            values_dict = {}
            min_date = df[variable_name].min()
            max_date = df[variable_name].max()
            values_dict["earliest date"] = min_date
            values_dict["latest_date"] = max_date
        else:
            values_dict = {"-": "-"}
    else:
        values_dict = {"Too many values to show": "-"}

    # Create the entry
    entry = {
        "variable_name": variable_name,
        "variable_label": variable_label,
        "variable_category": variable_category,
        "variable_type": variable_type,
        "question_text": question_text,
        "num_missing": num_missing,
        "num_unique": num_unique,
        "values": values_dict,
        "notes": notes,
    }

    print(entry)
    # Append to entries
    ENTRIES.append(entry)

# %%
def return_codebook_entry_nested(
    ENTRIES,
    df,
    header_df,
    header_col,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
    show_values=True,
):
    keys = df[variable_name].iloc[0].keys()
    cols = [f"{variable_name}_{c}" for c in keys]

    num_missing = 0
    for _, row in df.iterrows():
        response_dict = row[variable_name]
        num_missing_row = 0
        for k, v in response_dict.items():
            if k != "other_text":
                if pd.isna(v):
                    num_missing_row += 1
        if num_missing_row > 0:
            num_missing += 1
    num_unique = df[variable_name].astype(str).nunique()  # unique combos

    entry = {
        "variable_name": variable_name,
        "variable_label": variable_label,
        "variable_category": variable_category,
        "variable_type": variable_type,
        "question_text": question_text,
        "num_missing": num_missing,
        "num_unique": num_unique,
    }

    if show_values:
        values = []
        # INNER LEVEL
        for c in keys:
            inner_dict = {}
            inner_variable_name = c
            inner_variable_label = header_df[header_df["header"] == c][header_col].iloc[
                0
            ]

            if c == "other":
                inner_variable_label = "Other (selected)"
            elif c == "other_text":
                inner_variable_label = "Other (typed text)"

            match_column = f"{variable_name}_{c}"
            inner_values_dict = {}
            if "other_text" in inner_variable_name:
                for stat in ["mean", "std", "min", "max"]:
                    inner_values_dict[f"{stat} chars"] = np.round(
                        df[match_column].str.len().describe().to_dict()[stat], 1
                    )
            else:
                if variable_name == "lm_usecases":  # binary
                    inner_values_dict = (
                        df[match_column]
                        .astype(bool)
                        .value_counts(dropna=False)
                        .to_dict()
                    )
                elif variable_name in [
                    "stated_prefs",
                    "performance_attributes",
                    "choice_attributes",
                ]:
                    for stat in ["mean", "std", "min", "max"]:
                        inner_values_dict[stat] = np.round(
                            df[match_column].describe().to_dict()[stat], 1
                        )

            inner_dict["variable_name"] = inner_variable_name
            inner_dict["variable_label"] = inner_variable_label
            for k, v in inner_values_dict.items():
                inner_dict[k] = v

            values.append(inner_dict)
        entry["values"] = {"nested_values": values}

    else:
        entry["values"] = {"-": "-"}

    entry["notes"] = notes
    ENTRIES.append(entry)
    print(entry)

# %% [markdown]
# ## The Survey

# %%
# Start new entry set
ENTRIES = []

survey = data_dict["survey"]

print(survey.columns)

# Unnest the columns
survey = unnest_columns(data_dict["survey"])

print(survey.columns)
# Out:
# Index(['user_id', 'survey_only', 'num_completed_conversations',
#        'timing_duration_s', 'timing_duration_mins', 'generated_datetime',
#        'consent', 'consent_age', 'lm_familiarity', 'lm_indirect_use',
#        'lm_direct_use', 'lm_frequency_use', 'self_description',
#        'system_string', 'age', 'gender', 'employment_status', 'education',
#        'marital_status', 'english_proficiency', 'study_id', 'study_locale',
#        'religion', 'ethnicity', 'location', 'lm_usecases', 'stated_prefs',
#        'order_lm_usecases', 'order_stated_prefs', 'included_in_US_REP',
#        'included_in_UK_REP', 'included_in_balanced_subset'],
#       dtype='object')
# Index(['user_id', 'survey_only', 'num_completed_conversations',
#        'timing_duration_s', 'timing_duration_mins', 'generated_datetime',
#        'consent', 'consent_age', 'lm_familiarity', 'lm_indirect_use',
#        ...
#        'order_lm_usecases_other', 'order_stated_prefs_values',
#        'order_stated_prefs_creativity', 'order_stated_prefs_fluency',
#        'order_stated_prefs_factuality', 'order_stated_prefs_diversity',
#        'order_stated_prefs_safety', 'order_stated_prefs_personalisation',
#        'order_stated_prefs_helpfulness', 'order_stated_prefs_other'],
#       dtype='object', length=106)

# %% [markdown]
# ### Base columns

# %%
# Base columns
variable_name = "user_id"
variable_label = "Unique participant identifier"
variable_category = "meta"
variable_type = "string id"
question_text = "-"
notes = "Pseudonymized from Prolific worker ID. Used to link survey data to conversation data. In our paper, we refer to `users' as `participants'."
return_codebook_entry(
    ENTRIES,
    survey,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)

variable_name = "survey_only"
variable_label = "Indicator if participant only completed the survey, or also completed conversations"
variable_category = "meta"
variable_type = "binary"
question_text = "-"
notes = ""
return_codebook_entry(
    ENTRIES,
    survey,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)

variable_name = "num_completed_conversations"
variable_label = "Number of conversations that a participant completed"
variable_category = "meta"
variable_type = "int"
question_text = "-"
notes = ""
return_codebook_entry(
    ENTRIES,
    survey,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)
# Out:
# {'variable_name': 'user_id', 'variable_label': 'Unique participant identifier', 'variable_category': 'meta', 'variable_type': 'string id', 'question_text': '-', 'num_missing': 0, 'num_unique': 1500, 'values': {'-': '-'}, 'notes': "Pseudonymized from Prolific worker ID. Used to link survey data to conversation data. In our paper, we refer to `users' as `participants'."}
# {'variable_name': 'survey_only', 'variable_label': 'Indicator if participant only completed the survey, or also completed conversations', 'variable_category': 'meta', 'variable_type': 'binary', 'question_text': '-', 'num_missing': 0, 'num_unique': 2, 'values': {False: 1396, True: 104}, 'notes': ''}
# {'variable_name': 'num_completed_conversations', 'variable_label': 'Number of conversations that a participant completed', 'variable_category': 'meta', 'variable_type': 'int', 'question_text': '-', 'num_missing': 0, 'num_unique': 8, 'values': {'mean': 5.3, 'std': 1.7, 'min': 0.0, 'max': 7.0}, 'notes': ''}

# %%
# Timing
variable_name = "timing_duration_s"
variable_label = "Duration of the survey session (in seconds)"
variable_category = "meta"
variable_type = "float"
question_text = "-"
notes = (
    "Extreme values are caused by participants completing task in multiple sessions."
)
return_codebook_entry(
    ENTRIES,
    survey,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)


variable_name = "timing_duration_mins"
variable_label = "Duration of the survey session (in minutes)"
variable_category = "constructed"
variable_type = "float"
notes = "timing_duration_s / 60. Extreme values are caused by participants completing task in multiple sessions."
return_codebook_entry(
    ENTRIES,
    survey,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)
# Out:
# {'variable_name': 'timing_duration_s', 'variable_label': 'Duration of the survey session (in seconds)', 'variable_category': 'meta', 'variable_type': 'float', 'question_text': '-', 'num_missing': 0, 'num_unique': 977, 'values': {'mean': 2154.2, 'std': 20557.1, 'min': 160.0, 'max': 529927.0}, 'notes': 'Extreme values are caused by participants completing task in multiple sessions.'}
# {'variable_name': 'timing_duration_mins', 'variable_label': 'Duration of the survey session (in minutes)', 'variable_category': 'constructed', 'variable_type': 'float', 'question_text': '-', 'num_missing': 0, 'num_unique': 977, 'values': {'mean': 35.9, 'std': 342.6, 'min': 2.7, 'max': 8832.1}, 'notes': 'timing_duration_s / 60. Extreme values are caused by participants completing task in multiple sessions.'}

# %%
# Generated datetime
variable_name = "generated_datetime"
variable_label = "Recorded date of the survey completion"
variable_category = "meta"
variable_type = "datetime"
question_text = "-"
notes = "End time, not start time"
return_codebook_entry(
    ENTRIES,
    survey,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)
# Out:
# {'variable_name': 'generated_datetime', 'variable_label': 'Recorded date of the survey completion', 'variable_category': 'meta', 'variable_type': 'datetime', 'question_text': '-', 'num_missing': 0, 'num_unique': 1492, 'values': {'earliest date': '2023-11-22 15:48:46', 'latest_date': '2023-12-22 06:56:27'}, 'notes': 'End time, not start time'}

# %%
# Consent
variable_name = "consent"
variable_label = "Participant informed consent confirmation"
variable_category = "direct"
variable_type = "categorical"
question_text = survey_mapping_dict["consent"]["full_question"]
notes = "See full informed consent document for details"
return_codebook_entry(
    ENTRIES,
    survey,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)

# Consent age
variable_name = "consent_age"
variable_label = "Participant age confirmation"
variable_category = "direct"
variable_type = "categorical"
question_text = survey_mapping_dict["consent_age"]["full_question"]
notes = "See full informed consent document for details"
return_codebook_entry(
    ENTRIES,
    survey,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)
# Out:
# {'variable_name': 'consent', 'variable_label': 'Participant informed consent confirmation', 'variable_category': 'direct', 'variable_type': 'categorical', 'question_text': 'If you have read the information above and agree to participate with the understanding that the data (including any personal data) you submit will be processed accordingly, please select the box below to start.', 'num_missing': 0, 'num_unique': 1, 'values': {'Yes, I consent to take part': 1500}, 'notes': 'See full informed consent document for details'}
# {'variable_name': 'consent_age', 'variable_label': 'Participant age confirmation', 'variable_category': 'direct', 'variable_type': 'categorical', 'question_text': 'Please note that you may only participate in this survey if you are 18 years of age or over.', 'num_missing': 0, 'num_unique': 1, 'values': {'I certify that I am 18 years of age or over': 1500}, 'notes': 'See full informed consent document for details'}

# %% [markdown]
# ### LLM columns

# %%
# LLM familiarity
variable_name = "lm_familiarity"
variable_label = "Familiarity with LLMs"
variable_category = "direct"
variable_type = "categorical"
question_text = survey_mapping_dict["lm_familiarity"]["full_question"]
notes = ""
return_codebook_entry(
    ENTRIES,
    survey,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)

# Direct use
variable_name = "lm_direct_use"
variable_label = "Direct use of LLMs"
variable_category = "direct"
variable_type = "categorical"
question_text = survey_mapping_dict["lm_direct_use"]["full_question"]
notes = ""
return_codebook_entry(
    ENTRIES,
    survey,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)

# Indirect use
variable_name = "lm_indirect_use"
variable_label = "Direct use of LLMs"
variable_category = "direct"
variable_type = "categorical"
question_text = survey_mapping_dict["lm_direct_use"]["full_question"]
notes = ""
return_codebook_entry(
    ENTRIES,
    survey,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)

# Frequency of use
variable_name = "lm_frequency_use"
variable_label = "Frequency of using Large Language Models"
variable_category = "direct"
variable_type = "categorical"
question_text = survey_mapping_dict["lm_frequency_use"]["full_question"]
notes = "Only shown if lm_indirect_use==1 OR lm_direct_use==1. Null indicates particiant did not see question."
return_codebook_entry(
    ENTRIES,
    survey,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)
# Out:
# {'variable_name': 'lm_familiarity', 'variable_label': 'Familiarity with LLMs', 'variable_category': 'direct', 'variable_type': 'categorical', 'question_text': 'How familiar are you with AI language models like ChatGPT?', 'num_missing': 0, 'num_unique': 3, 'values': {'Somewhat familiar': 920, 'Very familiar': 424, 'Not familiar at all': 156}, 'notes': ''}
# {'variable_name': 'lm_direct_use', 'variable_label': 'Direct use of LLMs', 'variable_category': 'direct', 'variable_type': 'categorical', 'question_text': 'Have you directly used or communicated with an AI language model, such as asking questions to ChatGPT, BARD, Claude or other similar models?', 'num_missing': 0, 'num_unique': 3, 'values': {'Yes': 1162, 'No': 259, 'Unsure': 79}, 'notes': ''}
# {'variable_name': 'lm_indirect_use', 'variable_label': 'Direct use of LLMs', 'variable_category': 'direct', 'variable_type': 'categorical', 'question_text': 'Have you directly used or communicated with an AI language model, such as asking questions to ChatGPT, BARD, Claude or other similar models?', 'num_missing': 0, 'num_unique': 3, 'values': {'Yes': 1104, 'No': 215, 'Unsure': 181}, 'notes': ''}
# {'variable_name': 'lm_frequency_use', 'variable_label': 'Frequency of using Large Language Models', 'variable_category': 'direct', 'variable_type': 'categorical', 'question_text': 'How often do you use or communicate with AI language models?', 'num_missing': 247, 'num_unique': 5, 'values': {'Once per month': 374, 'Every week': 316, 'More than once a month': 291, None: 247, 'Less than one a year': 162, 'Every day': 110}, 'notes': 'Only shown if lm_indirect_use==1 OR lm_direct_use==1. Null indicates particiant did not see question.'}

# %% [markdown]
# ### Nested usecase and prefs columns

# %%
variable_name = "lm_usecases"
variable_label = "Use cases of LLMs"
variable_category = "direct"
variable_type = "dict"
header_df = header_usecases
header_col = "survey_text"
question_text = (
    header_df["survey_text"][header_df["header"] == "shared_opener"]
    .iloc[0]
    .split("-")[0]
    .strip()
)
notes = """Question only show if lm_direct_use==1 OR lm_indirect_use==1.
N Missing indicates the participants who have at least one missing value in the usecases (besides from 'other_text').
N Unique indicates the unique combinations of use cases selected by participants.
On 'other_text', Null indicates participant did not type anything.
On all other keys, 0 indicates participant saw question and did not select usecase. Null indicates participant did not see question."""
return_codebook_entry_nested(
    ENTRIES,
    survey,
    header_df,
    header_col,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)
# Out:
# {'variable_name': 'lm_usecases', 'variable_label': 'Use cases of LLMs', 'variable_category': 'direct', 'variable_type': 'dict', 'question_text': 'Which of the following scenarios best describe how and why you use AI language models? Select all that apply.', 'num_missing': 247, 'num_unique': 853, 'values': {'nested_values': [{'variable_name': 'homework_assistance', 'variable_label': '**Homework Assistance**: Getting help with school or university assignments.', False: 967, True: 533}, {'variable_name': 'research', 'variable_label': '**Research**: Fact-checking or gaining overviews on specific topics.', True: 864, False: 636}, {'variable_name': 'source_suggestions', 'variable_label': '**Source Suggestions**: Creating or finding bibliographies, information sources or reading lists.', False: 1036, True: 464}, {'variable_name': 'professional_work', 'variable_label': '**Professional Work**: Assisting in drafting, editing, or brainstorming content for work.', False: 784, True: 716}, {'variable_name': 'creative_writing', 'variable_label': '**Creative Writing**: Generating story ideas, dialogues, poems or other writing prompts.', False: 861, True: 639}, {'variable_name': 'casual_conversation', 'variable_label': '**Casual Conversation**: Engaging in small talk, casual chats, or joke generation.', False: 991, True: 509}, {'variable_name': 'personal_recommendations', 'variable_label': '**Personal Recommendations**: Seeking book, music or movie recommendations.', False: 987, True: 513}, {'variable_name': 'daily_productivity', 'variable_label': '**Daily Productivity**: Setting reminders, making to-do lists, or productivity tips.', False: 1037, True: 463}, {'variable_name': 'technical_or_programming_help', 'variable_label': '**Technical or Programming Help**: Seeking programming guidance, code generation, software recommendations, or debugging assistance.', False: 916, True: 584}, {'variable_name': 'travel_guidance', 'variable_label': '**Travel Guidance**: Getting destination recommendations, planning holidays, or cultural etiquette tips.', False: 1120, True: 380}, {'variable_name': 'lifestyle_and_hobbies', 'variable_label': '**Lifestyle and Hobbies**: Looking for recipes, craft ideas, home decoration tips, or hobby-related information.', False: 943, True: 557}, {'variable_name': 'well-being_guidance', 'variable_label': '**Well-being Guidance**: Seeking general exercise routines, wellness or meditation tips.', False: 1094, True: 406}, {'variable_name': 'medical_guidance', 'variable_label': '**Medical Guidance**: Seeking health-related advice or medical guidance.', False: 1123, True: 377}, {'variable_name': 'financial_guidance', 'variable_label': '**Financial Guidance**: Asking about financial concepts or general investing ideas.', False: 1146, True: 354}, {'variable_name': 'games', 'variable_label': '**Games**: Playing text-based games, generating riddles or puzzles.', False: 1110, True: 390}, {'variable_name': 'historical_or_news_insight', 'variable_label': '**Historical or News Insight**: Getting summaries or background on historical events or news and current affairs.', False: 1070, True: 430}, {'variable_name': 'relationship_advice', 'variable_label': '**Relationship Advice**: Seeking general self-help or relationship advice for family, friends or partners.', False: 1155, True: 345}, {'variable_name': 'language_learning', 'variable_label': '**Language Learning**: Using it as a tool for language practice or translation.', False: 1024, True: 476}, {'variable_name': 'other', 'variable_label': 'Other (selected)', False: 1129, True: 371}, {'variable_name': 'other_text', 'variable_label': 'Other (typed text)', 'mean chars': 45.8, 'std chars': 41.9, 'min chars': 3.0, 'max chars': 328.0}]}, 'notes': "Question only show if lm_direct_use==1 OR lm_indirect_use==1.\nN Missing indicates the participants who have at least one missing value in the usecases (besides from 'other_text').\nN Unique indicates the unique combinations of use cases selected by ...

# %%
variable_name = "order_lm_usecases"
variable_label = "Use cases of LLMs (order of options presented in survey)"
variable_category = "meta"
variable_type = "dict"
header_df = header_usecases
header_col = "survey_text"
question_text = "-"
notes = """Integer 1-18 indicating random order that usecase option was presented to participant.
For 'other', option is always shown last so will always be 19.
Null indicates participant did not see question.
The usecases as the same as in lm_usecases."""
return_codebook_entry_nested(
    ENTRIES,
    survey,
    header_df,
    header_col,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
    show_values=False,
)
# Out:
# {'variable_name': 'order_lm_usecases', 'variable_label': 'Use cases of LLMs (order of options presented in survey)', 'variable_category': 'meta', 'variable_type': 'dict', 'question_text': '-', 'num_missing': 247, 'num_unique': 1254, 'values': {'-': '-'}, 'notes': "Integer 1-18 indicating random order that usecase option was presented to participant.\nFor 'other', option is always shown last so will always be 19.\nNull indicates participant did not see question.\nThe usecases as the same as in lm_usecases."}

# %%
variable_name = "stated_prefs"
variable_label = "Stated preferences over LLM behaviours"
variable_category = "direct"
variable_type = "dict"
header_df = header_prefs
header_col = "survey_text"
question_text = """Rate each of the following statements about your opinion on the importance of different AI language model behaviors or traits.
It is important that an AI language model..."""
notes = """Sliders from [Strongly disagree] to [Strongly agree] are recorded on a 0-100 scale. Participant does not see numeric value.
N Missing indicates the participants who have at least one missing value in the attributes (besides from 'other_text').
N Unique indicates the unique combinations of use cases selected by participants.
On 'other_text', Null indicates participant did not type anything.
Note that this scale (on Qualtrics) runs 0-100. The Conversations rating scales (for choice_attributes, performance_attributes on Dynabench) run 1-100.
"""

return_codebook_entry_nested(
    ENTRIES,
    survey,
    header_df,
    header_col,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)
# Out:
# {'variable_name': 'stated_prefs', 'variable_label': 'Stated preferences over LLM behaviours', 'variable_category': 'direct', 'variable_type': 'dict', 'question_text': 'Rate each of the following statements about your opinion on the importance of different AI language model behaviors or traits.\nIt is important that an AI language model...', 'num_missing': 0, 'num_unique': 1475, 'values': {'nested_values': [{'variable_name': 'values', 'variable_label': '...reflects my values or cultural perspectives', 'mean': 54.3, 'std': 26.3, 'min': 0.0, 'max': 100.0}, {'variable_name': 'creativity', 'variable_label': '...produces responses that are creative and inspiring', 'mean': 69.6, 'std': 22.1, 'min': 0.0, 'max': 100.0}, {'variable_name': 'fluency', 'variable_label': '...produces responses that are well-written and coherent', 'mean': 86.7, 'std': 16.3, 'min': 2.0, 'max': 100.0}, {'variable_name': 'factuality', 'variable_label': '...produces factual and informative responses', 'mean': 88.7, 'std': 16.2, 'min': 0.0, 'max': 100.0}, {'variable_name': 'diversity', 'variable_label': '...summarises multiple viewpoints or different worldviews', 'mean': 75.7, 'std': 20.0, 'min': 0.0, 'max': 100.0}, {'variable_name': 'safety', 'variable_label': '...produces responses that are safe and do not risk harm to myself and others', 'mean': 80.2, 'std': 25.2, 'min': 0.0, 'max': 100.0}, {'variable_name': 'personalisation', 'variable_label': '...learns from our conversations and feels personalised to me', 'mean': 67.9, 'std': 24.6, 'min': 0.0, 'max': 100.0}, {'variable_name': 'helpfulness', 'variable_label': '...produces responses that are helpful and relevant to my requests', 'mean': 89.4, 'std': 14.4, 'min': 0.0, 'max': 100.0}, {'variable_name': 'other', 'variable_label': 'Other (selected)', 'mean': 57.5, 'std': 19.0, 'min': 0.0, 'max': 100.0}, {'variable_name': 'other_text', 'variable_label': 'Other (typed text)', 'mean chars': 32.6, 'std chars': 24.4, 'min chars': 1.0, 'max chars': 144.0}]}, 'notes': "Sliders from [Strongly disagree] to [Strongly agree] are recorded on a 0-100 scale. Participant does not see numeric value.\nN Missing indicates the participants who have at least one missing value in the attributes (besides from 'other_text').\nN Unique indicates the unique combinations of use cases selected by participants.\nOn 'other_text', Null indicates participant did not type anything.\nNote that this scale (on Qualtrics) runs 0-100. The Conversations rating scales (for choice_attributes, performance_attributes on Dynabench) run 1-100.\n"}

# %%
variable_name = "order_stated_prefs"
variable_label = (
    "Stated preferences over LLM behaviours (order of options presented in survey)"
)
variable_category = "meta"
variable_type = "dict"
header_df = header_prefs
header_col = "survey_text"
question_text = "-"
notes = """Integer 1-8 indicating random order that attribute slider was presented to participant.
For 'other', option is always shown last so will always be 9.
Null indicates participant did not see question.
The attributes as the same as in stated_prefs."""
return_codebook_entry_nested(
    ENTRIES,
    survey,
    header_df,
    header_col,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
    show_values=False,
)
# Out:
# {'variable_name': 'order_stated_prefs', 'variable_label': 'Stated preferences over LLM behaviours (order of options presented in survey)', 'variable_category': 'meta', 'variable_type': 'dict', 'question_text': '-', 'num_missing': 0, 'num_unique': 1467, 'values': {'-': '-'}, 'notes': "Integer 1-8 indicating random order that attribute slider was presented to participant.\nFor 'other', option is always shown last so will always be 9.\nNull indicates participant did not see question.\nThe attributes as the same as in stated_prefs."}

# %% [markdown]
# ### Text columns

# %%
variable_name = "self_description"
variable_label = "Participant self-written profile describing themself"
variable_category = "direct"
variable_type = "string"
question_text = survey_mapping_dict["self_description"]["full_question"]
notes = ""
return_codebook_entry(
    ENTRIES,
    survey,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)

variable_name = "system_string"
variable_label = "Participant self-written system string, constitution or custom instructions for an LLM"
variable_category = "direct"
variable_type = "string"
question_text = survey_mapping_dict["system_string"]["full_question"]
notes = ""
return_codebook_entry(
    ENTRIES,
    survey,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)
# Out:
# {'variable_name': 'self_description', 'variable_label': 'Participant self-written profile describing themself', 'variable_category': 'direct', 'variable_type': 'string', 'question_text': "Please briefly describe your values, core beliefs, guiding principles in life, or other things that are important to you. For example, you might include values you'd want to teach to your children or qualities you look for in friends. There are no right or wrong answers. Please do not provide any personally identifiable details like your name, address or email. Please write 2-5 sentences in your own words.", 'num_missing': 0, 'num_unique': 1500, 'values': {'mean chars': 241.3, 'std chars': 134.6, 'min chars': 3.0, 'max chars': 1547.0}, 'notes': ''}
# {'variable_name': 'system_string', 'variable_label': 'Participant self-written system string, constitution or custom instructions for an LLM', 'variable_category': 'direct', 'variable_type': 'string', 'question_text': "Imagine you are instructing an AI language model how to behave. You can think of this like a set of core principles that the AI language model will always try to follow, no matter what task you ask it to perform. In your own words, describe what characteristics, personality traits or features you believe the AI should consistently exhibit. You can also instruct the model what behaviours or content you don't want to see. If you envision the AI behaving differently in various contexts (e.g., professional assistance vs. storytelling), please specify the general adaptations you'd like to see. Please write 2-5 sentences in your own words.", 'num_missing': 0, 'num_unique': 1500, 'values': {'mean chars': 260.4, 'std chars': 288.4, 'min chars': 16.0, 'max chars': 9530.0}, 'notes': ''}

# %% [markdown]
# ### Demographic columns

# %%
# Basic demographics
cols = [
    "age",
    "education",
    "employment_status",
    "marital_status",
    "english_proficiency",
]
for c in cols:
    variable_name = c
    variable_label = c.replace("_", " ").title()
    variable_category = "direct"
    variable_type = "categorical"
    question_text = survey_mapping_dict[c]["full_question"]
    notes = ""
    return_codebook_entry(
        ENTRIES,
        survey,
        variable_name,
        variable_label,
        variable_category,
        variable_type,
        question_text,
        notes,
    )

# Gender
variable_name = "gender"
variable_label = "Gender"
variable_category = "constructed"
variable_type = "categorical"
question_text = survey_mapping_dict[c]["full_question"]
notes = "Participants could chose Male, Female, Non-binary / third Gender, Prefer not to say, or write in their own response. Two independent annotators then categorised the self-describe responses only when abundantly clear they fit another category. See paper for details."
return_codebook_entry(
    ENTRIES,
    survey,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)
# Out:
# {'variable_name': 'age', 'variable_label': 'Age', 'variable_category': 'direct', 'variable_type': 'categorical', 'question_text': 'How old are you?', 'num_missing': 0, 'num_unique': 7, 'values': {'25-34 years old': 454, '18-24 years old': 297, '35-44 years old': 237, '45-54 years old': 208, '55-64 years old': 197, '65+ years old': 106, 'Prefer not to say': 1}, 'notes': ''}
# {'variable_name': 'education', 'variable_label': 'Education', 'variable_category': 'direct', 'variable_type': 'categorical', 'question_text': 'What is the highest level of education you have completed?', 'num_missing': 0, 'num_unique': 9, 'values': {'University Bachelors Degree': 637, 'Graduate / Professional degree': 241, 'Some University but no degree': 236, 'Completed Secondary School': 209, 'Vocational': 125, 'Some Secondary': 24, 'Completed Primary School': 16, 'Prefer not to say': 9, 'Some Primary': 3}, 'notes': ''}
# {'variable_name': 'employment_status', 'variable_label': 'Employment Status', 'variable_category': 'direct', 'variable_type': 'categorical', 'question_text': 'What best describes your employment status over the last three months?', 'num_missing': 0, 'num_unique': 8, 'values': {'Working full-time': 712, 'Working part-time': 265, 'Student': 191, 'Unemployed, seeking work': 113, 'Retired': 104, 'Homemaker / Stay-at-home parent': 46, 'Unemployed, not seeking work': 46, 'Prefer not to say': 23}, 'notes': ''}
# {'variable_name': 'marital_status', 'variable_label': 'Marital Status', 'variable_category': 'direct', 'variable_type': 'categorical', 'question_text': 'What is your current marital status?', 'num_missing': 0, 'num_unique': 5, 'values': {'Never been married': 870, 'Married': 463, 'Divorced / Separated': 123, 'Prefer not to say': 23, 'Widowed': 21}, 'notes': ''}
# {'variable_name': 'english_proficiency', 'variable_label': 'English Proficiency', 'variable_category': 'direct', 'variable_type': 'categorical', 'question_text': 'How would you describe your proficiency in English?', 'num_missing': 0, 'num_unique': 5, 'values': {'Native speaker': 886, 'Fluent': 405, 'Advanced': 160, 'Intermediate': 42, 'Basic': 7}, 'notes': ''}
# {'variable_name': 'gender', 'variable_label': 'Gender', 'variable_category': 'constructed', 'variable_type': 'categorical', 'question_text': 'How would you describe your proficiency in English?', 'num_missing': 0, 'num_unique': 4, 'values': {'Male': 757, 'Female': 718, 'Non-binary / third gender': 21, 'Prefer not to say': 4}, 'notes': 'Participants could chose Male, Female, Non-binary / third Gender, Prefer not to say, or write in their own response. Two independent annotators then categorised the self-describe responses only when abundantly clear they fit another category. See paper for details.'}

# %%
# Religion and Ethnicity (nested)
for c in ["religion", "ethnicity"]:
    variable_name = c
    variable_label = f"Dictionary of {c} information."
    variable_category = "NA"
    variable_type = "dict"
    question_text = "-"
    notes = "Keys explained below."
    return_codebook_entry(
        ENTRIES,
        survey,
        variable_name,
        variable_label,
        variable_category,
        variable_type,
        question_text,
        notes,
    )

    variable_name = f"{c}_self_described"
    variable_label = "Participant {c} self-description"
    variable_category = "direct"
    variable_type = "string"
    question_text = (
        survey_mapping_dict[f"{c}_1_text"]["full_question"].split("-")[0].strip()
    )
    notes = (
        "Participant had option to type and Self Describe or select Prefer not to say."
    )
    return_codebook_entry(
        ENTRIES,
        survey,
        variable_name,
        variable_label,
        variable_category,
        variable_type,
        question_text,
        notes,
    )

    variable_name = f"{c}_categorised"
    variable_label = f"Granular categories of participant {c}"
    variable_category = "constructed"
    variable_type = "categorical"
    question_text = "-"
    notes = "Two independent annotators manually verified all automated classifications (gpt-4-turbo) of the self-describe string. See paper for details."
    return_codebook_entry(
        ENTRIES,
        survey,
        variable_name,
        variable_label,
        variable_category,
        variable_type,
        question_text,
        notes,
    )

    variable_name = f"{c}_simplified"
    variable_label = f"Simplified categories of participant {c}"
    variable_category = "constructed"
    variable_type = "categorical"
    question_text = "-"
    notes = f"Simplified version of {c}_categorised for more aggregate analysis."
    return_codebook_entry(
        ENTRIES,
        survey,
        variable_name,
        variable_label,
        variable_category,
        variable_type,
        question_text,
        notes,
    )
# Out:
# {'variable_name': 'religion', 'variable_label': 'Dictionary of religion information.', 'variable_category': 'NA', 'variable_type': 'dict', 'question_text': '-', 'num_missing': '-', 'num_unique': '-', 'values': {'-': '-'}, 'notes': 'Keys explained below.'}
# {'variable_name': 'religion_self_described', 'variable_label': 'Participant {c} self-description', 'variable_category': 'direct', 'variable_type': 'string', 'question_text': 'What is your religious affiliation?', 'num_missing': 0, 'num_unique': 137, 'values': {'mean chars': 12.2, 'std chars': 5.7, 'min chars': 2.0, 'max chars': 112.0}, 'notes': 'Participant had option to type and Self Describe or select Prefer not to say.'}
# {'variable_name': 'religion_categorised', 'variable_label': 'Granular categories of participant religion', 'variable_category': 'constructed', 'variable_type': 'categorical', 'question_text': '-', 'num_missing': 0, 'num_unique': 12, 'values': {'Non-religious': 762, 'Christian': 487, 'Agnostic': 71, 'Prefer not to say': 59, 'Jewish': 42, 'Muslim': 31, 'Spiritual': 18, 'Buddhist': 12, 'Folk religion': 6, 'Hindu': 5, 'Other': 4, 'Sikh': 3}, 'notes': 'Two independent annotators manually verified all automated classifications (gpt-4-turbo) of the self-describe string. See paper for details.'}
# {'variable_name': 'religion_simplified', 'variable_label': 'Simplified categories of participant religion', 'variable_category': 'constructed', 'variable_type': 'categorical', 'question_text': '-', 'num_missing': 0, 'num_unique': 6, 'values': {'No Affiliation': 851, 'Christian': 487, 'Prefer not to say': 59, 'Jewish': 42, 'Muslim': 31, 'Other': 30}, 'notes': 'Simplified version of religion_categorised for more aggregate analysis.'}
# {'variable_name': 'ethnicity', 'variable_label': 'Dictionary of ethnicity information.', 'variable_category': 'NA', 'variable_type': 'dict', 'question_text': '-', 'num_missing': '-', 'num_unique': '-', 'values': {'-': '-'}, 'notes': 'Keys explained below.'}
# {'variable_name': 'ethnicity_self_described', 'variable_label': 'Participant {c} self-description', 'variable_category': 'direct', 'variable_type': 'string', 'question_text': 'What is your ethnicity?', 'num_missing': 0, 'num_unique': 264, 'values': {'mean chars': 9.2, 'std chars': 6.2, 'min chars': 3.0, 'max chars': 99.0}, 'notes': 'Participant had option to type and Self Describe or select Prefer not to say.'}
# {'variable_name': 'ethnicity_categorised', 'variable_label': 'Granular categories of participant ethnicity', 'variable_category': 'constructed', 'variable_type': 'categorical', 'question_text': '-', 'num_missing': 0, 'num_unique': 9, 'values': {'White': 969, 'Black / African': 122, 'Hispanic / Latino': 121, 'Asian': 95, 'Prefer not to say': 86, 'Mixed': 68, 'Other': 17, 'Middle Eastern / Arab': 14, 'Indigenous / First Peoples': 8}, 'notes': 'Two independent annotators manually verified all automated classifications (gpt-4-turbo) of the self-describe string. See paper for details.'}
# {'variable_name': 'ethnicity_simplified', 'variable_label': 'Simplified categories of participant ethnicity', 'variable_category': 'constructed', 'variable_type': 'categorical', 'question_text': '-', 'num_missing': 0, 'num_unique': 7, 'values': {'White': 969, 'Black': 122, 'Hispanic': 121, 'Asian': 95, 'Prefer not to say': 86, 'Mixed': 68, 'Other': 39}, 'notes': 'Simplified version of ethnicity_categorised for more aggregate analysis.'}

# %%
variable_name = "location"
variable_label = "Dictionary of location information."
variable_category = "NA"
variable_type = "dict"
question_text = "-"
notes = "Keys explained below."
return_codebook_entry(
    ENTRIES,
    survey,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)


for c, l in zip(["birth", "reside"], ["birth", "residence"]):
    # Location (nested)
    variable_name = f"location_{c}_country"
    variable_label = f"Participant country of {l}"
    variable_category = "direct"
    variable_type = "categorical"
    if c == "birth":
        question_text = "In which country were you born?"
    elif c == "reside":
        question_text = "In which country do you currently reside?"
    notes = "Selected from standardised dropdown country list."
    return_codebook_entry(
        ENTRIES,
        survey,
        variable_name,
        variable_label,
        variable_category,
        variable_type,
        question_text,
        notes,
        show_values=False,
    )

    variable_name = f"location_{c}_countryISO"
    variable_label = f"ISO 3166-1 alpha-3 code for the country of {l}"
    variable_category = "constructed"
    variable_type = "categorical"
    question_text = "-"
    notes = ""
    return_codebook_entry(
        ENTRIES,
        survey,
        variable_name,
        variable_label,
        variable_category,
        variable_type,
        question_text,
        notes,
        show_values=False,
    )

    variable_name = f"location_{c}_subregion"
    variable_label = f"Participant sub-region of {l}"
    variable_category = "constructed"
    variable_type = "categorical"
    question_text = "-"
    notes = f"Mapped from country of {l}, based on United Nations defined subregions."
    return_codebook_entry(
        ENTRIES,
        survey,
        variable_name,
        variable_label,
        variable_category,
        variable_type,
        question_text,
        notes,
        show_values=False,
    )


variable_name = "location_same_birth_reside_country"
variable_label = "Whether the participant was born and resides in the same country"
variable_category = "constructed"
variable_type = "binary"
question_text = "-"
notes = ""
return_codebook_entry(
    ENTRIES,
    survey,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)

variable_name = "location_special_region"
variable_label = "Adjusted regional categories for unique sample properties"
variable_category = "constructed"
variable_type = "categorical"
question_text = "-"
notes = "Within regions and sub-regions, some countries are split out to better represent sample density (e.g., treating UK and US samples seperately from Europe and North America)."
return_codebook_entry(
    ENTRIES,
    survey,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)
# Out:
# {'variable_name': 'location', 'variable_label': 'Dictionary of location information.', 'variable_category': 'NA', 'variable_type': 'dict', 'question_text': '-', 'num_missing': '-', 'num_unique': '-', 'values': {'-': '-'}, 'notes': 'Keys explained below.'}
# {'variable_name': 'location_birth_country', 'variable_label': 'Participant country of birth', 'variable_category': 'direct', 'variable_type': 'categorical', 'question_text': 'In which country were you born?', 'num_missing': 0, 'num_unique': 75, 'values': {'Too many values to show': '-'}, 'notes': 'Selected from standardised dropdown country list.'}
# {'variable_name': 'location_birth_countryISO', 'variable_label': 'ISO 3166-1 alpha-3 code for the country of birth', 'variable_category': 'constructed', 'variable_type': 'categorical', 'question_text': '-', 'num_missing': 0, 'num_unique': 75, 'values': {'Too many values to show': '-'}, 'notes': ''}
# {'variable_name': 'location_birth_subregion', 'variable_label': 'Participant sub-region of birth', 'variable_category': 'constructed', 'variable_type': 'categorical', 'question_text': '-', 'num_missing': 0, 'num_unique': 16, 'values': {'Too many values to show': '-'}, 'notes': 'Mapped from country of birth, based on United Nations defined subregions.'}
# {'variable_name': 'location_reside_country', 'variable_label': 'Participant country of residence', 'variable_category': 'direct', 'variable_type': 'categorical', 'question_text': 'In which country do you currently reside?', 'num_missing': 0, 'num_unique': 38, 'values': {'Too many values to show': '-'}, 'notes': 'Selected from standardised dropdown country list.'}
# {'variable_name': 'location_reside_countryISO', 'variable_label': 'ISO 3166-1 alpha-3 code for the country of residence', 'variable_category': 'constructed', 'variable_type': 'categorical', 'question_text': '-', 'num_missing': 0, 'num_unique': 38, 'values': {'Too many values to show': '-'}, 'notes': ''}
# {'variable_name': 'location_reside_subregion', 'variable_label': 'Participant sub-region of residence', 'variable_category': 'constructed', 'variable_type': 'categorical', 'question_text': '-', 'num_missing': 0, 'num_unique': 11, 'values': {'Too many values to show': '-'}, 'notes': 'Mapped from country of residence, based on United Nations defined subregions.'}
# {'variable_name': 'location_same_birth_reside_country', 'variable_label': 'Whether the participant was born and resides in the same country', 'variable_category': 'constructed', 'variable_type': 'binary', 'question_text': '-', 'num_missing': 0, 'num_unique': 3, 'values': {'Yes': 1320, 'No': 177, 'Prefer not to say': 3}, 'notes': ''}
# {'variable_name': 'location_special_region', 'variable_label': 'Adjusted regional categories for unique sample properties', 'variable_category': 'constructed', 'variable_type': 'categorical', 'question_text': '-', 'num_missing': 0, 'num_unique': 11, 'values': {'US': 338, 'Europe': 313, 'UK': 292, 'Latin America and the Caribbean': 146, 'Australia and New Zealand': 129, 'Africa': 118, 'Asia': 60, 'Northern America': 50, 'Middle East': 50, 'Prefer not to say': 3, 'Oceania': 1}, 'notes': 'Within regions and sub-regions, some countries are split out to better represent sample density (e.g., treating UK and US samples seperately from Europe and North America).'}

# %% [markdown]
# ### Study columns

# %%
# Study params
variable_name = "study_id"
variable_label = "Unique study idenfitier on Prolific"
variable_category = "meta"
variable_type = "string id"
question_text = "-"
notes = ""

return_codebook_entry(
    ENTRIES,
    survey,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)

variable_name = "study_locale"
variable_label = "Recruitment country of Prolific study"
variable_category = "meta"
variable_type = "categorical"
question_text = "-"
notes = ""
return_codebook_entry(
    ENTRIES,
    survey,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
    show_values=False,
)
# Out:
# {'variable_name': 'study_id', 'variable_label': 'Unique study idenfitier on Prolific', 'variable_category': 'meta', 'variable_type': 'string id', 'question_text': '-', 'num_missing': 0, 'num_unique': 51, 'values': {'-': '-'}, 'notes': ''}
# {'variable_name': 'study_locale', 'variable_label': 'Recruitment country of Prolific study', 'variable_category': 'meta', 'variable_type': 'categorical', 'question_text': '-', 'num_missing': 0, 'num_unique': 33, 'values': {'Too many values to show': '-'}, 'notes': ''}

# %% [markdown]
# ### Other constructed columns

# %%
# Other constructed columns
for r in ["UK", "US"]:
    variable_name = f"included_in_{r}_REP"
    variable_label = f"Indicator if participant was included in the rebalanced {r} representative sample"
    variable_category = "constructed"
    variable_type = "binary"
    question_text = "-"
    notes = "Census-representative samples were rebalanced to mitigate sampling issues. See paper for details."
    return_codebook_entry(
        ENTRIES,
        survey,
        variable_name,
        variable_label,
        variable_category,
        variable_type,
        question_text,
        notes,
    )

variable_name = "included_in_balanced_subset"
variable_label = (
    "Indicator if participant's conversations are included in the balanced subset"
)
variable_category = "constructed"
variable_type = "binary"
question_text = "-"
notes = """Balanced subset was created to equally sample conversations of three types (unguided, values, controversy).
We only include participants who have at least one of each conversation type, and then ensure equal numbers of each type are retained.
See paper for details."""
return_codebook_entry(
    ENTRIES,
    survey,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)
# Out:
# {'variable_name': 'included_in_UK_REP', 'variable_label': 'Indicator if participant was included in the rebalanced UK representative sample', 'variable_category': 'constructed', 'variable_type': 'binary', 'question_text': '-', 'num_missing': 0, 'num_unique': 2, 'values': {False: 1257, True: 243}, 'notes': 'Census-representative samples were rebalanced to mitigate sampling issues. See paper for details.'}
# {'variable_name': 'included_in_US_REP', 'variable_label': 'Indicator if participant was included in the rebalanced US representative sample', 'variable_category': 'constructed', 'variable_type': 'binary', 'question_text': '-', 'num_missing': 0, 'num_unique': 2, 'values': {False: 1270, True: 230}, 'notes': 'Census-representative samples were rebalanced to mitigate sampling issues. See paper for details.'}
# {'variable_name': 'included_in_balanced_subset', 'variable_label': "Indicator if participant's conversations are included in the balanced subset", 'variable_category': 'constructed', 'variable_type': 'binary', 'question_text': '-', 'num_missing': 0, 'num_unique': 2, 'values': {True: 1246, False: 254}, 'notes': 'Balanced subset was created to equally sample conversations of three types (unguided, values, controversy).\nWe only include participants who have at least one of each conversation type, and then ensure equal numbers of each type are retained.\nSee paper for details.'}

# %%
SURVEY_ENTRIES = ENTRIES
print(f"There are {len(SURVEY_ENTRIES)} entries in the survey codebook.")
# Out:
# There are 46 entries in the survey codebook.

# %% [markdown]
# ## The Conversations

# %%
# Start new entry set for conversations
ENTRIES = []
conversations = data_dict["conversations"]
print(conversations.columns)

# Unnest the columns
nested_columns = ["performance_attributes", "choice_attributes"]
conversations = unnest_columns(conversations, nested_columns)

print(conversations.columns)
# Out:
# Index(['conversation_id', 'user_id', 'included_in_balanced_subset',
#        'generated_datetime', 'timing_duration_s', 'timing_duration_mins',
#        'conversation_type', 'opening_prompt', 'conversation_turns',
#        'conversation_history', 'performance_attributes', 'choice_attributes',
#        'open_feedback'],
#       dtype='object')
# Index(['conversation_id', 'user_id', 'included_in_balanced_subset',
#        'generated_datetime', 'timing_duration_s', 'timing_duration_mins',
#        'conversation_type', 'opening_prompt', 'conversation_turns',
#        'conversation_history', 'performance_attributes', 'choice_attributes',
#        'open_feedback', 'performance_attributes_values',
#        'performance_attributes_fluency', 'performance_attributes_factuality',
#        'performance_attributes_safety', 'performance_attributes_diversity',
#        'performance_attributes_creativity',
#        'performance_attributes_helpfulness', 'choice_attributes_values',
#        'choice_attributes_fluency', 'choice_attributes_factuality',
#        'choice_attributes_safety', 'choice_attributes_diversity',
#        'choice_attributes_creativity', 'choice_attributes_helpfulness'],
#       dtype='object')

# %% [markdown]
# ### Base columns

# %%
# Base columns
variable_name = "user_id"
variable_label = "Unique participant identifier"
variable_category = "meta"
variable_type = "string id"
question_text = "-"
notes = "Pseudonymized from Prolific worker ID. Used to link conversation data to survey data."
return_codebook_entry(
    ENTRIES,
    conversations,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)

variable_name = "conversation_id"
variable_label = "Unique conversation identifier"
variable_category = "meta"
variable_type = "string id"
question_text = "-"
notes = ""
return_codebook_entry(
    ENTRIES,
    conversations,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)

variable_name = "included_in_balanced_subset"
variable_label = (
    "Indicator if participant's conversations are included in the balanced subset"
)
variable_category = "constructed"
variable_type = "binary"
question_text = "-"
notes = """Balanced subset was created to equally sample conversations of three types (unguided, values, controversy).
We only include participants who have at least one of each conversation type, and then ensure equal numbers of each type are retained.
See paper for details."""
return_codebook_entry(
    ENTRIES,
    conversations,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)
# Out:
# {'variable_name': 'user_id', 'variable_label': 'Unique participant identifier', 'variable_category': 'meta', 'variable_type': 'string id', 'question_text': '-', 'num_missing': 0, 'num_unique': 1396, 'values': {'-': '-'}, 'notes': 'Pseudonymized from Prolific worker ID. Used to link conversation data to survey data.'}
# {'variable_name': 'conversation_id', 'variable_label': 'Unique conversation identifier', 'variable_category': 'meta', 'variable_type': 'string id', 'question_text': '-', 'num_missing': 0, 'num_unique': 8011, 'values': {'-': '-'}, 'notes': ''}
# {'variable_name': 'included_in_balanced_subset', 'variable_label': "Indicator if participant's conversations are included in the balanced subset", 'variable_category': 'constructed', 'variable_type': 'binary', 'question_text': '-', 'num_missing': 0, 'num_unique': 2, 'values': {True: 6696, False: 1315}, 'notes': 'Balanced subset was created to equally sample conversations of three types (unguided, values, controversy).\nWe only include participants who have at least one of each conversation type, and then ensure equal numbers of each type are retained.\nSee paper for details.'}

# %%
# Timing
variable_name = "timing_duration_s"
variable_label = "Duration of the conversation (in seconds)"
variable_category = "meta"
variable_type = "float"
question_text = "-"
notes = (
    "Extreme values are caused by participants completing task in multiple sessions."
)
return_codebook_entry(
    ENTRIES,
    conversations,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)


variable_name = "timing_duration_mins"
variable_label = "Duration of the conversation (in minutes)"
variable_category = "constructed"
variable_type = "float"
notes = "timing_duration_s / 60. Extreme values are caused by participants completing task in multiple sessions."
return_codebook_entry(
    ENTRIES,
    conversations,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)
# Out:
# {'variable_name': 'timing_duration_s', 'variable_label': 'Duration of the conversation (in seconds)', 'variable_category': 'meta', 'variable_type': 'float', 'question_text': '-', 'num_missing': 0, 'num_unique': 7656, 'values': {'mean': 555.9, 'std': 422.1, 'min': 73.5, 'max': 17145.8}, 'notes': 'Extreme values are caused by participants completing task in multiple sessions.'}
# {'variable_name': 'timing_duration_mins', 'variable_label': 'Duration of the conversation (in minutes)', 'variable_category': 'constructed', 'variable_type': 'float', 'question_text': '-', 'num_missing': 0, 'num_unique': 1948, 'values': {'mean': 9.3, 'std': 7.0, 'min': 1.2, 'max': 285.8}, 'notes': 'timing_duration_s / 60. Extreme values are caused by participants completing task in multiple sessions.'}

# %%
# Generated datetime
variable_name = "generated_datetime"
variable_label = "Recorded date of the conversation completion"
variable_category = "meta"
variable_type = "datetime"
question_text = "-"
notes = "Recorded at end of conversation, before fine-grained feedback page shown."
return_codebook_entry(
    ENTRIES,
    conversations,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)
# Out:
# {'variable_name': 'generated_datetime', 'variable_label': 'Recorded date of the conversation completion', 'variable_category': 'meta', 'variable_type': 'datetime', 'question_text': '-', 'num_missing': 0, 'num_unique': 7820, 'values': {'earliest date': '2023-11-22 15:55:46', 'latest_date': '2023-12-22 08:04:46'}, 'notes': 'Recorded at end of conversation, before fine-grained feedback page shown.'}

# %% [markdown]
# ### Text columns

# %%
variable_name = "opening_prompt"
variable_label = "Opening human-written prompt of the conversation"
variable_category = "direct"
variable_type = "string"
question_text = "Now start the conversation with your question, request or statement."
notes = """We provide the following soft guidance:
Need some inspiration? You can request help with a task (like writing a recipe, organising an activity or event, completing an assignment)... You can chitchat, have casual conversation or seek personal advice. You can ask questions about the world, current events or your viewpoints."""
return_codebook_entry(
    ENTRIES,
    conversations,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)

variable_name = "open_feedback"
variable_label = "Participant written feedback on the conversation as a whole."
variable_category = "direct"
variable_type = "string"
question_text = """Give the model some feedback on the conversation as whole. Hypothetically, what would an ideal interaction for you look like here? What was good and what was bad? What (if anything) was missing? What would you change to make the conversation better?
Please write 2-5 sentences in your own words."""
notes = "Entry box reads: Enter text here. Do not copy and paste."
return_codebook_entry(
    ENTRIES,
    conversations,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)
# Out:
# {'variable_name': 'opening_prompt', 'variable_label': 'Opening human-written prompt of the conversation', 'variable_category': 'direct', 'variable_type': 'string', 'question_text': 'Now start the conversation with your question, request or statement.', 'num_missing': 0, 'num_unique': 7811, 'values': {'mean chars': 65.7, 'std chars': 59.2, 'min chars': 2.0, 'max chars': 1195.0}, 'notes': 'We provide the following soft guidance:\nNeed some inspiration? You can request help with a task (like writing a recipe, organising an activity or event, completing an assignment)... You can chitchat, have casual conversation or seek personal advice. You can ask questions about the world, current events or your viewpoints.'}
# {'variable_name': 'open_feedback', 'variable_label': 'Participant written feedback on the conversation as a whole.', 'variable_category': 'direct', 'variable_type': 'string', 'question_text': 'Give the model some feedback on the conversation as whole. Hypothetically, what would an ideal interaction for you look like here? What was good and what was bad? What (if anything) was missing? What would you change to make the conversation better?\nPlease write 2-5 sentences in your own words.', 'num_missing': 0, 'num_unique': 7953, 'values': {'mean chars': 160.1, 'std chars': 106.4, 'min chars': 2.0, 'max chars': 1581.0}, 'notes': 'Entry box reads: Enter text here. Do not copy and paste.'}

# %% [markdown]
# ### Convo columns

# %%
variable_name = "conversation_type"
variable_label = "Type of conversation (from pre-defined categories)"
variable_category = "direct"
variable_type = "categorical"
question_text = """Choose what type of conversation you want to have."""
notes = """Participants pick from the following radio buttons:
Unguided. Ask, request or talk to the model about anything . It is up to you!
Values guided. Ask, request or talk to the model about something important to you or that represents your values. This could be related to work, religion, family and relationship, politics or culture.
Controversy guided. Ask, request or talk to the model about something controversial or where people would disagree in your community, culture or country.
We also provide the additional instruction: Remember if you are here as a paid study participant, you need to do two of each type. If you are here as a volunteer, then take your pick!
"""
return_codebook_entry(
    ENTRIES,
    conversations,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)
# Out:
# {'variable_name': 'conversation_type', 'variable_label': 'Type of conversation (from pre-defined categories)', 'variable_category': 'direct', 'variable_type': 'categorical', 'question_text': 'Choose what type of conversation you want to have.', 'num_missing': 0, 'num_unique': 3, 'values': {'unguided': 3113, 'values guided': 2460, 'controversy guided': 2438}, 'notes': 'Participants pick from the following radio buttons:\nUnguided. Ask, request or talk to the model about anything . It is up to you!\nValues guided. Ask, request or talk to the model about something important to you or that represents your values. This could be related to work, religion, family and relationship, politics or culture.\nControversy guided. Ask, request or talk to the model about something controversial or where people would disagree in your community, culture or country.\nWe also provide the additional instruction: Remember if you are here as a paid study participant, you need to do two of each type. If you are here as a volunteer, then take your pick!\n'}

# %%
variable_name = "conversation_turns"
variable_label = "Number of human-model turns (back-and-forths) in the conversation."
variable_category = "meta"
variable_type = "int"
question_text = "-"
notes = """We force 2 turns as the minimum. After the opening turn, we give the instruction:
Now continue the conversation. Conversations can be between 2 and 10 turns. Try to vary the length. When you're done, click Finish."""
return_codebook_entry(
    ENTRIES,
    conversations,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)
# Out:
# {'variable_name': 'conversation_turns', 'variable_label': 'Number of human-model turns (back-and-forths) in the conversation.', 'variable_category': 'meta', 'variable_type': 'int', 'question_text': '-', 'num_missing': 0, 'num_unique': 13, 'values': {'mean': 3.4, 'std': 1.6, 'min': 2.0, 'max': 22.0}, 'notes': "We force 2 turns as the minimum. After the opening turn, we give the instruction:\nNow continue the conversation. Conversations can be between 2 and 10 turns. Try to vary the length. When you're done, click Finish."}

# %%
variable_name = "conversation_history"
variable_label = "Full conversation history (human and model messages, with scores and model metadata)"
variable_category = "direct"
variable_type = "dict"
question_text = "-"
notes = """We provide an example of what this nested conversation history looks like below."""
return_codebook_entry(
    ENTRIES,
    conversations,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
    show_values=False,
)
# Out:
# {'variable_name': 'conversation_history', 'variable_label': 'Full conversation history (human and model messages, with scores and model metadata)', 'variable_category': 'direct', 'variable_type': 'dict', 'question_text': '-', 'num_missing': '-', 'num_unique': '-', 'values': {'Too many values to show': '-'}, 'notes': 'We provide an example of what this nested conversation history looks like below.'}

# %% [markdown]
# ### Nested attribute columns

# %%
variable_name = "performance_attributes"
variable_label = (
    "How well the top-rated model response performed across different attributes"
)
variable_category = "nested"
variable_type = "dict"
question_text = """Tell us how the model performed. Consider your first message and the top-rated response.
Rate the following statements about the performance across different attributes.
This response..."""
notes = """Sliders from [Performed very poorly] to [Performed very well] are recorded on a 1-100 scale. Participant does not see numeric value.
Note that the attributes align choice_attributes, as well as with the stated preference ratings from The Survey.
Participants had option to select N/A, which is recorded as Null.
N Missing indicates the number of participants who have at least one missing value in the nested columns.
N Unique indicates the unique combinations of use cases selected by participants.
There was no option for 'other'.
Note, these sliders run from 1-100 (on Dynabench). The sliders for stated_prefs (in Survey on Qualtrics) run 0-100."""
header_df = header_prefs
header_col = "conversations_performance_factors"
return_codebook_entry_nested(
    ENTRIES,
    conversations,
    header_df,
    header_col,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)
# Out:
# {'variable_name': 'performance_attributes', 'variable_label': 'How well the top-rated model response performed across different attributes', 'variable_category': 'nested', 'variable_type': 'dict', 'question_text': 'Tell us how the model performed. Consider your first message and the top-rated response.\nRate the following statements about the performance across different attributes.\nThis response...', 'num_missing': 1824, 'num_unique': 7532, 'values': {'nested_values': [{'variable_name': 'values', 'variable_label': '...reflected my values or cultural perspective', 'mean': 74.1, 'std': 22.2, 'min': 1.0, 'max': 100.0}, {'variable_name': 'fluency', 'variable_label': '...was well-written and coherent', 'mean': 84.3, 'std': 18.3, 'min': 1.0, 'max': 100.0}, {'variable_name': 'factuality', 'variable_label': '...was factual and informative', 'mean': 79.2, 'std': 21.5, 'min': 1.0, 'max': 100.0}, {'variable_name': 'safety', 'variable_label': "...was safe and doesn't risk harm to myself and others", 'mean': 85.1, 'std': 19.3, 'min': 1.0, 'max': 100.0}, {'variable_name': 'diversity', 'variable_label': '...summarised multiple viewpoints or different worldviews', 'mean': 68.7, 'std': 25.3, 'min': 1.0, 'max': 100.0}, {'variable_name': 'creativity', 'variable_label': '...was creative and inspiring', 'mean': 63.7, 'std': 26.1, 'min': 1.0, 'max': 100.0}, {'variable_name': 'helpfulness', 'variable_label': '...was helpful and relevant to my request', 'mean': 81.5, 'std': 21.9, 'min': 1.0, 'max': 100.0}]}, 'notes': "Sliders from [Performed very poorly] to [Performed very well] are recorded on a 1-100 scale. Participant does not see numeric value.\nNote that the attributes align choice_attributes, as well as with the stated preference ratings from The Survey.\nParticipants had option to select N/A, which is recorded as Null.\nN Missing indicates the number of participants who have at least one missing value in the nested columns.\nN Unique indicates the unique combinations of use cases selected by participants.\nThere was no option for 'other'.\nNote, these sliders run from 1-100 (on Dynabench). The sliders for stated_prefs (in Survey on Qualtrics) run 0-100."}

# %%
variable_name = "choice_attributes"
variable_label = "How different attributes influenced the participant's choice of the top-rated model response"
variable_category = "direct"
variable_type = "dict"
question_text = """Tell us why you chose this response over others. Consider your first message and top-rated response compared to other responses.
Rate the following statements about the importance of different attributes in your decision.
I chose this response..."""
notes = """Sliders from [Very unimportant] to [Very important] are recorded on a 1-100 scale. Participant does not see numeric value.
Note that the attributes align with performance_attributes, as well as the stated preference ratings from The Survey.
Participants had option to select N/A, which is recorded as Null.
num_missing indicates the number of participants who have at least one missing value in the nested columns.
num_unique indicates the unique combinations of use cases selected by participants.
There was no option for 'other'.
Note, these sliders run from 1-100 (on Dynabench). The sliders for stated_prefs (in Survey on Qualtrics) run 0-100."""
header_df = header_prefs
header_col = "conversations_performance_factors"
return_codebook_entry_nested(
    ENTRIES,
    conversations,
    header_df,
    header_col,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)
# Out:
# {'variable_name': 'choice_attributes', 'variable_label': "How different attributes influenced the participant's choice of the top-rated model response", 'variable_category': 'direct', 'variable_type': 'dict', 'question_text': 'Tell us why you chose this response over others. Consider your first message and top-rated response compared to other responses.\nRate the following statements about the importance of different attributes in your decision.\nI chose this response...', 'num_missing': 1740, 'num_unique': 7526, 'values': {'nested_values': [{'variable_name': 'values', 'variable_label': '...reflected my values or cultural perspective', 'mean': 66.9, 'std': 27.2, 'min': 1.0, 'max': 100.0}, {'variable_name': 'fluency', 'variable_label': '...was well-written and coherent', 'mean': 82.5, 'std': 18.5, 'min': 1.0, 'max': 100.0}, {'variable_name': 'factuality', 'variable_label': '...was factual and informative', 'mean': 79.3, 'std': 21.0, 'min': 1.0, 'max': 100.0}, {'variable_name': 'safety', 'variable_label': "...was safe and doesn't risk harm to myself and others", 'mean': 72.1, 'std': 27.8, 'min': 1.0, 'max': 100.0}, {'variable_name': 'diversity', 'variable_label': '...summarised multiple viewpoints or different worldviews', 'mean': 66.0, 'std': 26.5, 'min': 1.0, 'max': 100.0}, {'variable_name': 'creativity', 'variable_label': '...was creative and inspiring', 'mean': 62.1, 'std': 27.1, 'min': 1.0, 'max': 100.0}, {'variable_name': 'helpfulness', 'variable_label': '...was helpful and relevant to my request', 'mean': 82.5, 'std': 20.0, 'min': 1.0, 'max': 100.0}]}, 'notes': "Sliders from [Very unimportant] to [Very important] are recorded on a 1-100 scale. Participant does not see numeric value.\nNote that the attributes align with performance_attributes, as well as the stated preference ratings from The Survey.\nParticipants had option to select N/A, which is recorded as Null.\nnum_missing indicates the number of participants who have at least one missing value in the nested columns.\nnum_unique indicates the unique combinations of use cases selected by participants.\nThere was no option for 'other'.\nNote, these sliders run from 1-100 (on Dynabench). The sliders for stated_prefs (in Survey on Qualtrics) run 0-100."}

# %%
CONVO_ENTRIES = ENTRIES
print(f"There are {len(CONVO_ENTRIES)} entries in the convos codebook.")
# Out:
# There are 13 entries in the convos codebook.

# %% [markdown]
# ## The Utterances

# %%
# Start new entry set for utterances
ENTRIES = []
utterances = data_dict["utterances"]
print(utterances.columns)
# Out:
# Index(['utterance_id', 'interaction_id', 'conversation_id', 'user_id', 'turn',
#        'within_turn_id', 'included_in_balanced_subset', 'conversation_type',
#        'user_prompt', 'model_response', 'model_name', 'model_provider',
#        'score', 'if_chosen'],
#       dtype='object')

# %% [markdown]
# ### Basic columns

# %%
# Base columns
variable_name = "user_id"
variable_label = "Unique participant identifier"
variable_category = "meta"
variable_type = "string id"
question_text = "-"
notes = (
    "Pseudonymized from Prolific worker ID. Used to link utterance data to survey data."
)
return_codebook_entry(
    ENTRIES,
    utterances,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)

variable_name = "conversation_id"
variable_label = "Unique conversation identifier"
variable_category = "meta"
variable_type = "string id"
question_text = "-"
notes = "Used to link utterance data to conversation data."
return_codebook_entry(
    ENTRIES,
    utterances,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)

variable_name = "interaction_id"
variable_label = "Unique interaction identifier, where an interaction is a turn within a conversation (single human message with multiple model responses)"
variable_category = "meta"
variable_type = "string id"
question_text = "-"
notes = ""
return_codebook_entry(
    ENTRIES,
    utterances,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)

variable_name = "utterance_id"
variable_label = "Unique utterance identifier, where an utterance is a single human message - single model response pair"
variable_category = "meta"
variable_type = "string id"
question_text = "-"
notes = ""
return_codebook_entry(
    ENTRIES,
    utterances,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)

variable_name = "within_turn_id"
variable_label = (
    "Within turn identifier of up to four model responses to a single human message"
)
variable_category = "meta"
variable_type = "string id"
question_text = "-"
notes = "Order is random, not based on score or presentation in interface"
return_codebook_entry(
    ENTRIES,
    utterances,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)

variable_name = "included_in_balanced_subset"
variable_label = (
    "Indicator if participant's conversations are included in the balanced subset"
)
variable_category = "constructed"
variable_type = "binary"
question_text = "-"
notes = """Balanced subset was created to equally sample conversations of three types (unguided, values, controversy).
We only include participants who have at least one of each conversation type, and then ensure equal numbers of each type are retained.
See paper for details."""
return_codebook_entry(
    ENTRIES,
    utterances,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)
# Out:
# {'variable_name': 'user_id', 'variable_label': 'Unique participant identifier', 'variable_category': 'meta', 'variable_type': 'string id', 'question_text': '-', 'num_missing': 0, 'num_unique': 1396, 'values': {'-': '-'}, 'notes': 'Pseudonymized from Prolific worker ID. Used to link utterance data to survey data.'}
# {'variable_name': 'conversation_id', 'variable_label': 'Unique conversation identifier', 'variable_category': 'meta', 'variable_type': 'string id', 'question_text': '-', 'num_missing': 0, 'num_unique': 8011, 'values': {'-': '-'}, 'notes': 'Used to link utterance data to conversation data.'}
# {'variable_name': 'interaction_id', 'variable_label': 'Unique interaction identifier, where an interaction is a turn within a conversation (single human message with multiple model responses)', 'variable_category': 'meta', 'variable_type': 'string id', 'question_text': '-', 'num_missing': 0, 'num_unique': 27172, 'values': {'-': '-'}, 'notes': ''}
# {'variable_name': 'utterance_id', 'variable_label': 'Unique utterance identifier, where an utterance is a single human message - single model response pair', 'variable_category': 'meta', 'variable_type': 'string id', 'question_text': '-', 'num_missing': 0, 'num_unique': 68371, 'values': {'-': '-'}, 'notes': ''}
# {'variable_name': 'within_turn_id', 'variable_label': 'Within turn identifier of up to four model responses to a single human message', 'variable_category': 'meta', 'variable_type': 'string id', 'question_text': '-', 'num_missing': 0, 'num_unique': 4, 'values': {'-': '-'}, 'notes': 'Order is random, not based on score or presentation in interface'}
# {'variable_name': 'included_in_balanced_subset', 'variable_label': "Indicator if participant's conversations are included in the balanced subset", 'variable_category': 'constructed', 'variable_type': 'binary', 'question_text': '-', 'num_missing': 0, 'num_unique': 2, 'values': {True: 57401, False: 10970}, 'notes': 'Balanced subset was created to equally sample conversations of three types (unguided, values, controversy).\nWe only include participants who have at least one of each conversation type, and then ensure equal numbers of each type are retained.\nSee paper for details.'}

# %% [markdown]
# ### Utterance columns

# %%
variable_name = "conversation_type"
variable_label = "Type of conversation (from pre-defined categories)"
variable_category = "direct"
variable_type = "categorical"
question_text = """Choose what type of conversation you want to have."""
notes = """Participants pick from the following radio buttons:
Unguided. Ask, request or talk to the model about anything . It is up to you!
Values guided. Ask, request or talk to the model about something important to you or that represents your values . This could be related to work, religion, family and relationship, politics or culture.
Controversy guided. Ask, request or talk to the model about something controversial or where people would disagree in your community, culture or country.
We also provide the additional instruction: Remember if you are here as a paid study participant, you need to do two of each type. If you are here as a volunteer, then take your pick!
"""
return_codebook_entry(
    ENTRIES,
    conversations,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)
# Out:
# {'variable_name': 'conversation_type', 'variable_label': 'Type of conversation (from pre-defined categories)', 'variable_category': 'direct', 'variable_type': 'categorical', 'question_text': 'Choose what type of conversation you want to have.', 'num_missing': 0, 'num_unique': 3, 'values': {'unguided': 3113, 'values guided': 2460, 'controversy guided': 2438}, 'notes': 'Participants pick from the following radio buttons:\nUnguided. Ask, request or talk to the model about anything . It is up to you!\nValues guided. Ask, request or talk to the model about something important to you or that represents your values . This could be related to work, religion, family and relationship, politics or culture.\nControversy guided. Ask, request or talk to the model about something controversial or where people would disagree in your community, culture or country.\nWe also provide the additional instruction: Remember if you are here as a paid study participant, you need to do two of each type. If you are here as a volunteer, then take your pick!\n'}

# %%
variable_name = "turn"
variable_label = "Turn of conversation when prompt was entered"
variable_category = "meta"
variable_type = "int"
question_text = "-"
notes = "In the paper, we refer to the first turn as T=1. Here, we index the first turn as 0."
return_codebook_entry(
    ENTRIES,
    utterances,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)
# Out:
# {'variable_name': 'turn', 'variable_label': 'Turn of conversation when prompt was entered', 'variable_category': 'meta', 'variable_type': 'int', 'question_text': '-', 'num_missing': 0, 'num_unique': 22, 'values': {'mean': 1.2, 'std': 1.6, 'min': 0.0, 'max': 21.0}, 'notes': 'In the paper, we refer to the first turn as T=1. Here, we index the first turn as 0.'}

# %% [markdown]
# ### Model metadata

# %%
variable_name = "model_name"
variable_label = "Name of LLM"
variable_category = "meta"
variable_type = "categorical"
question_text = "-"
notes = """We provide the long name as it appeared on our backend.
We provide a mapping of long names to shorter more familiar names on our Github or in the paper."""
return_codebook_entry(
    ENTRIES,
    utterances,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)
# Out:
# {'variable_name': 'model_name', 'variable_label': 'Name of LLM', 'variable_category': 'meta', 'variable_type': 'categorical', 'question_text': '-', 'num_missing': 0, 'num_unique': 21, 'values': {'command': 4812, 'claude-instant-1': 4292, 'models/chat-bison-001': 4168, 'HuggingFaceH4/zephyr-7b-beta': 4133, 'meta-llama/Llama-2-7b-chat-hf': 3995, 'command-light': 3929, 'command-nightly': 3816, 'gpt-4-1106-preview': 3735, 'gpt-4': 3515, 'meta-llama/Llama-2-70b-chat-hf': 3493, 'gpt-3.5-turbo': 3471, 'timdettmers/guanaco-33b-merged': 3468, 'claude-2.1': 3338, 'mistralai/Mistral-7B-Instruct-v0.1': 3261, 'claude-2': 3209, 'tiiuae/falcon-7b-instruct': 2608, 'OpenAssistant/oasst-sft-4-pythia-12b-epoch-3.5': 2314, 'meta-llama/Llama-2-13b-chat-hf': 1744, 'luminous-supreme-control': 1722, 'google/flan-t5-xxl': 1715, 'luminous-extended-control': 1633}, 'notes': 'We provide the long name as it appeared on our backend.\nWe provide a mapping of long names to shorter more familiar names on our Github or in the paper.'}

# %%
variable_name = "model_provider"
variable_label = "Provider of the LLM"
variable_category = "meta"
variable_type = "categorical"
question_text = "-"
notes = """Note for open-access LLMs, HuggingFace API is always listed as the source and does not imply they built the model."""
return_codebook_entry(
    ENTRIES,
    utterances,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)
# Out:
# {'variable_name': 'model_provider', 'variable_label': 'Provider of the LLM', 'variable_category': 'meta', 'variable_type': 'categorical', 'question_text': '-', 'num_missing': 0, 'num_unique': 6, 'values': {'huggingface_api': 26731, 'cohere': 12557, 'anthropic': 10839, 'openai': 10721, 'google': 4168, 'aleph': 3355}, 'notes': 'Note for open-access LLMs, HuggingFace API is always listed as the source and does not imply they built the model.'}

# %% [markdown]
# ### Text columns

# %%
variable_name = "user_prompt"
variable_label = "Human-written message."
variable_category = "direct"
variable_type = "string"
question_text = "-"
notes = ""
return_codebook_entry(
    ENTRIES,
    utterances,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)
# Out:
# {'variable_name': 'user_prompt', 'variable_label': 'Human-written message.', 'variable_category': 'direct', 'variable_type': 'string', 'question_text': '-', 'num_missing': 0, 'num_unique': 26673, 'values': {'mean chars': 69.9, 'std chars': 62.0, 'min chars': 1.0, 'max chars': 1311.0}, 'notes': ''}

# %%
variable_name = "model_response"
variable_label = "Model-generated response"
variable_category = "direct"
variable_type = "string"
question_text = "-"
notes = "An empty string is stored as `EMPTY STRING'."
return_codebook_entry(
    ENTRIES,
    utterances,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)
# Out:
# {'variable_name': 'model_response', 'variable_label': 'Model-generated response', 'variable_category': 'direct', 'variable_type': 'string', 'question_text': '-', 'num_missing': 0, 'num_unique': 66614, 'values': {'mean chars': 565.3, 'std chars': 387.9, 'min chars': 1.0, 'max chars': 4630.0}, 'notes': "An empty string is stored as `EMPTY STRING'."}

# %% [markdown]
# ### Score related columns

# %%
variable_name = "score"
variable_label = "Score of the model response"
variable_category = "direct"
variable_type = "int"
question_text = "Rate the model responses. There are no right or wrong answers. Use your subjective judgement."
notes = """Sliders from [Terrible] to [Perfect] are recorded on a 1-100 scale. Participant does not see numeric value."""
return_codebook_entry(
    ENTRIES,
    utterances,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)
# Out:
# {'variable_name': 'score', 'variable_label': 'Score of the model response', 'variable_category': 'direct', 'variable_type': 'int', 'question_text': 'Rate the model responses. There are no right or wrong answers. Use your subjective judgement.', 'num_missing': 0, 'num_unique': 100, 'values': {'mean': 65.1, 'std': 29.3, 'min': 1.0, 'max': 100.0}, 'notes': 'Sliders from [Terrible] to [Perfect] are recorded on a 1-100 scale. Participant does not see numeric value.'}

# %%
variable_name = "if_chosen"
variable_label = "Whether model response was highest-rated by participant"
variable_category = "constructed"
variable_type = "binary"
question_text = "-"
notes = "In case of a tie, a random response is chosen."
return_codebook_entry(
    ENTRIES,
    utterances,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)
# Out:
# {'variable_name': 'if_chosen', 'variable_label': 'Whether model response was highest-rated by participant', 'variable_category': 'constructed', 'variable_type': 'binary', 'question_text': '-', 'num_missing': 0, 'num_unique': 2, 'values': {False: 40934, True: 27437}, 'notes': 'In case of a tie, a random response is chosen.'}

# %%
UTTER_ENTRIES = ENTRIES
print(f"There are {len(UTTER_ENTRIES)} entries in the utterances codebook.")
# Out:
# There are 14 entries in the utterances codebook.

# %% [markdown]
# ## The MetaData

# %%
# Start new entry set for metadata
ENTRIES = []

metadata = data_dict["metadata"]
metadata.columns
# Out:
# Index(['column_id', 'user_id', 'conversation_id', 'interaction_id',
#        'utterance_id', 'pii_flag', 'pii_manual_flag', 'language_flag',
#        'en_flag', 'moderation_flag'],
#       dtype='object')

# %% [markdown]
# ### Base columns

# %%
# Base columns
variable_name = "column_id"
variable_label = "Source of text utterance"
variable_category = "meta"
variable_type = "categorical"
question_text = "-"
notes = ""
return_codebook_entry(
    ENTRIES,
    metadata,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)


variable_name = "user_id"
variable_label = "Unique participant identifier"
variable_category = "meta"
variable_type = "string id"
question_text = "-"
notes = "Pseudonymized from Prolific worker ID. Used to link metadata to main data."
return_codebook_entry(
    ENTRIES,
    metadata,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)

variable_name = "conversation_id"
variable_label = "Unique conversation identifier"
variable_category = "meta"
variable_type = "string id"
question_text = "-"
notes = "Used to link metadata to main data."
return_codebook_entry(
    ENTRIES,
    metadata,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)

variable_name = "interaction_id"
variable_label = "Unique interaction identifier, where an interaction is a turn within a conversation (single human message with multiple model responses)"
variable_category = "meta"
variable_type = "string id"
question_text = "-"
notes = "Used to link metadata to main data."
return_codebook_entry(
    ENTRIES,
    metadata,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)

variable_name = "utterance_id"
variable_label = "Unique utterance identifier, where an utterance is a single human message - single model response pair"
variable_category = "meta"
variable_type = "string id"
question_text = "-"
notes = "Used to link metadata to main data."
return_codebook_entry(
    ENTRIES,
    metadata,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)
# Out:
# {'variable_name': 'column_id', 'variable_label': 'Source of text utterance', 'variable_category': 'meta', 'variable_type': 'categorical', 'question_text': '-', 'num_missing': 0, 'num_unique': 5, 'values': {'model_response': 68371, 'user_prompt': 27172, 'open_feedback': 8011, 'self_description': 1500, 'system_string': 1500}, 'notes': ''}
# {'variable_name': 'user_id', 'variable_label': 'Unique participant identifier', 'variable_category': 'meta', 'variable_type': 'string id', 'question_text': '-', 'num_missing': 0, 'num_unique': 1500, 'values': {'-': '-'}, 'notes': 'Pseudonymized from Prolific worker ID. Used to link metadata to main data.'}
# {'variable_name': 'conversation_id', 'variable_label': 'Unique conversation identifier', 'variable_category': 'meta', 'variable_type': 'string id', 'question_text': '-', 'num_missing': 3000, 'num_unique': 8011, 'values': {'-': '-'}, 'notes': 'Used to link metadata to main data.'}
# {'variable_name': 'interaction_id', 'variable_label': 'Unique interaction identifier, where an interaction is a turn within a conversation (single human message with multiple model responses)', 'variable_category': 'meta', 'variable_type': 'string id', 'question_text': '-', 'num_missing': 11011, 'num_unique': 27172, 'values': {'-': '-'}, 'notes': 'Used to link metadata to main data.'}
# {'variable_name': 'utterance_id', 'variable_label': 'Unique utterance identifier, where an utterance is a single human message - single model response pair', 'variable_category': 'meta', 'variable_type': 'string id', 'question_text': '-', 'num_missing': 38183, 'num_unique': 68371, 'values': {'-': '-'}, 'notes': 'Used to link metadata to main data.'}

# %% [markdown]
# ### Flag columns

# %%
variable_name = "pii_flag"
variable_label = "Automated flag for personally identifiable information"
variable_category = "meta"
variable_type = "binary"
question_text = "-"
notes = """Uses scrubadub https://scrubadub.readthedocs.io/en/stable/ to find PII. There may be some misclassifications.
Many of the inspected positives were false positives. All positive human-written texts checked.
See pii_manual_flag."""
return_codebook_entry(
    ENTRIES,
    metadata,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)
# Out:
# {'variable_name': 'pii_flag', 'variable_label': 'Automated flag for personally identifiable information', 'variable_category': 'meta', 'variable_type': 'binary', 'question_text': '-', 'num_missing': 0, 'num_unique': 2, 'values': {False: 105443, True: 1111}, 'notes': 'Uses scrubadub https://scrubadub.readthedocs.io/en/stable/ to find PII. There may be some misclassifications.\nMany of the inspected positives were false positives. All positive human-written texts checked.\nSee pii_manual_flag.'}

# %%
variable_name = "pii_manual_flag"
variable_label = (
    "Manual verification of personally identifiable information in human-written texts"
)
variable_category = "meta"
variable_type = "binary"
question_text = "-"
notes = """For any automated PII flags, we manually checked the human-written text for PII.
All were false positives so this flag overules the automated flag. We did not check model-generated text for PII.
NaN indicates entry was not manually checked."""
return_codebook_entry(
    ENTRIES,
    metadata,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)
# Out:
# {'variable_name': 'pii_manual_flag', 'variable_label': 'Manual verification of personally identifiable information in human-written texts', 'variable_category': 'meta', 'variable_type': 'binary', 'question_text': '-', 'num_missing': 106387, 'num_unique': 1, 'values': {nan: 106387, 0.0: 167}, 'notes': 'For any automated PII flags, we manually checked the human-written text for PII.\nAll were false positives so this flag overules the automated flag. We did not check model-generated text for PII.\nNaN indicates entry was not manually checked.'}

# %%
variable_name = "language_flag"
variable_label = "Automated language detection"
variable_category = "meta"
variable_type = "categorical"
question_text = "-"
notes = """Uses langid. There may be some misclassifications."""
return_codebook_entry(
    ENTRIES,
    metadata,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
    show_values=False,
)
# Out:
# {'variable_name': 'language_flag', 'variable_label': 'Automated language detection', 'variable_category': 'meta', 'variable_type': 'categorical', 'question_text': '-', 'num_missing': 0, 'num_unique': 59, 'values': {'Too many values to show': '-'}, 'notes': 'Uses langid. There may be some misclassifications.'}

# %%
variable_name = "en_flag"
variable_label = "Whether detected language is English"
variable_category = "meta"
variable_type = "binary"
question_text = "-"
notes = """Constructed based on automated language detection."""
return_codebook_entry(
    ENTRIES,
    metadata,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
    show_values=False,
)
# Out:
# {'variable_name': 'en_flag', 'variable_label': 'Whether detected language is English', 'variable_category': 'meta', 'variable_type': 'binary', 'question_text': '-', 'num_missing': 0, 'num_unique': 2, 'values': {'Too many values to show': '-'}, 'notes': 'Constructed based on automated language detection.'}

# %%
variable_name = "moderation_flag"
variable_label = "Automated flag for moderation"
variable_category = "meta"
variable_type = "nested dict"
question_text = "-"
notes = """Uses OpenAI moderation API. There may be some misclassifications.
Nested dictionary with binary flags and probabilities for sub-categories of harm."""
return_codebook_entry(
    ENTRIES,
    metadata,
    variable_name,
    variable_label,
    variable_category,
    variable_type,
    question_text,
    notes,
)
# Out:
# {'variable_name': 'moderation_flag', 'variable_label': 'Automated flag for moderation', 'variable_category': 'meta', 'variable_type': 'nested dict', 'question_text': '-', 'num_missing': '-', 'num_unique': '-', 'values': {'-': '-'}, 'notes': 'Uses OpenAI moderation API. There may be some misclassifications.\nNested dictionary with binary flags and probabilities for sub-categories of harm.'}

# %%
META_ENTRIES = ENTRIES
print(f"There are {len(META_ENTRIES)} entries in the utterances codebook.")
# Out:
# There are 10 entries in the utterances codebook.

# %% [markdown]
# ## Table Functions

# %%
def dict_depth(d, level=1):
    if not isinstance(d, dict) or not d:
        return level
    return max(dict_depth(v, level + 1) for k, v in d.items())

# %%
# Put into dataframe


def restructure_data(ENTRIES):
    df = pd.DataFrame(ENTRIES)

    display(df.head(3))

    new_rows = []

    for idx, row in df.iterrows():
        # First row entries appended as is
        header_row = ["HEADER"] + row[0:4].to_list()
        assert len(header_row) == 5
        new_rows.append([idx] + header_row)
        idx = ""
        # Now append the question text
        if row["question_text"] != "-":
            text_row = (
                ["TEXT"]
                + ["Question text:"]
                + [row["question_text"]]
                + ["*QEND*"]
                + [""]
            )
            assert len(text_row) == 5
            new_rows.append([idx] + text_row)
        # Now append the overall values
        for col, label in zip(
            ["num_missing", "num_unique"], ["N Missing:", "N Unique:"]
        ):
            if row[col] != "-":
                row_to_add = ["OVERALL"] + [""] + [""] + [label] + [row[col]]
                assert len(row_to_add) == 5
                new_rows.append([idx] + row_to_add)
        # Now append the nested values
        values = row["values"]
        if pd.isna(values) or "-" not in values.keys():
            depth = dict_depth(values)
            if "nested_values" not in values.keys():
                for k, v in values.items():
                    tag = "NESTED"
                    nested_row = [tag] + [""] + [f"*VSTART:*{k}"] + ["*VEND*"] + [v]
                    assert len(nested_row) == 5
                    new_rows.append([idx] + nested_row)
            elif "nested_values" in values.keys():
                list_of_values = values["nested_values"]
                for subitem_dict in list_of_values:
                    variable_name = subitem_dict["variable_name"]
                    variable_label = subitem_dict["variable_label"].replace("**", "")
                    tag = "NESTED HEADER"
                    nested_row = (
                        [tag]
                        + [variable_name]
                        + [f"*VHSTART:*{variable_label}"]
                        + ["*VHEND*"]
                        + [""]
                    )
                    new_rows.append([idx] + nested_row)
                    # Now add other items
                    for k, v in subitem_dict.items():
                        if k in ["variable_name", "variable_label"]:
                            continue
                        else:
                            tag = "NESTED"
                            nested_row = (
                                [tag] + [""] + [f"*VSTART:*{k}"] + ["*VEND*"] + [v]
                            )
                            new_rows.append([idx] + nested_row)

        if (row["notes"] == "") or (row["notes"] == "-"):
            continue
        else:
            notes_row = ["NOTES"] + ["Notes:"] + [row["notes"]] + ["*NEND*"] + [""]
            assert len(notes_row) == 5
            new_rows.append([idx] + notes_row)

    restructured_df = pd.DataFrame(
        new_rows,
        columns=["", "Tag", "VARIABLE", "LABEL", "CATEGORY", "TYPE"],
    )

    display(restructured_df.head(2))

    return restructured_df

# %%
# Style
def custom_format(val):
    if isinstance(val, (float)):
        # Format numeric values to two decimal places
        return f"{val:.1f}"
    else:
        # Return non-numeric values unaltered
        return val


# Function to insert custom LaTeX commands for highlighting rows
def midline_rows_latex(df):
    new_rows = []
    for index, row in df.iterrows():
        if row["Tag"] == "HEADER":
            # Inserting midrule before and after the header row
            new_rows.append([""] * 2 + ["MIDRULE"] + [""] * (df.shape[1] - 3))
            new_rows.append(row.values)
            new_rows.append([""] * 2 + ["MIDRULE"] + [""] * (df.shape[1] - 3))
        elif row["Tag"] == "TEXT":
            new_rows.append(row.values)
            new_rows.append([""] * 2 + ["CLINE"] + [""] * (df.shape[1] - 3))
        elif row["Tag"] == "NESTED HEADER":
            new_rows.append([""] * 2 + ["CLINE"] + [""] * (df.shape[1] - 3))
            new_rows.append(row.values)
        elif row["Tag"] == "NOTES":
            new_rows.append(row.values)
            new_rows.append([""] * 2 + ["CLINE"] + [""] * (df.shape[1] - 3))
        else:
            new_rows.append(row.values)
    return pd.DataFrame(new_rows, columns=df.columns)


def style_latex(restructured_df):

    # Apply midline rows
    lines_df = midline_rows_latex(restructured_df)

    # if header, make whole row bold
    def highlight_header(s):
        if s["Tag"] in ["HEADER", "NESTED_HEADER", "OVERALL"]:
            return ["font-weight: bold" for v in s]
        else:
            return ["" for v in s]

    # Apply the custom_format() function only to the Var Type column
    styled_df = lines_df.style.format(custom_format, subset="TYPE")

    # Apply bold styling
    styled_df = styled_df.apply(highlight_header, axis=1)

    # Bold the first row
    styled_df = styled_df.set_properties(
        **{"font-weight": "bold"}, subset=pd.IndexSlice[0, :]
    )

    # Color the cells in the Var Category column
    color_map = {
        "meta": "myred",
        "direct": "myyellow",
        "constructed": "mygreen",
        "string id": "myoat",
        "string": "myoat",
        "categorical": "myoat",
        "float": "myoat",
        "int": "myoat",
        "datetime": "myoat",
        "binary": "myoat",
        "dict": "myoat",
    }
    # Apply the colormap
    styled_df = styled_df.map(
        lambda val: f"background-color: {color_map[val]}" if val in color_map else ""
    )

    # Only display Var Name, Var Label, Var Category, Var Type
    styled_df = styled_df.hide(["Tag"], axis=1)
    styled_df = styled_df.hide(axis=0)

    # Escape latex characters
    styled_df = styled_df.format(escape="latex", subset=["VARIABLE", "LABEL"])

    # Convert to LaTeX
    latex_str = styled_df.to_latex(
        hrules=True,
        convert_css=True,
        environment="longtable",
    )

    # Edit the alignment
    latex_str = latex_str.replace(
        "lllll",
        "p{0.005\\textwidth}p{0.20\\textwidth}p{0.40\\textwidth}p{0.1\\textwidth}p{0.1\\textwidth}",
    )

    # Edit the midrule
    latex_str = "\\fontsize{6pt}{6pt}\\selectfont\n" + latex_str.replace(
        "& MIDRULE &  &  &  \\\\", "\\midrule"
    )

    # Edit the clins
    latex_str = latex_str.replace("CLINE &  &  &  \\\\", "\\cline{1-4}")

    # Replace question text
    latex_str = (
        latex_str.replace(
            "Question text: &",
            "\\multicolumn{4}{p{0.9\\textwidth}}{\\textit{Question text:}",
        )
    ).replace("& *QEND* &", "}")

    # Replace notes text
    latex_str = latex_str.replace(
        "Notes: &", "\\multicolumn{4}{p{0.9\\textwidth}}{\\textit{Notes:"
    ).replace("& *NEND* &", "}}")

    # Replace values text
    latex_str = latex_str.replace("*VSTART:*", "\\multicolumn{2}{r}{").replace(
        "& *VEND*", "}"
    )

    # Replace nested values text
    latex_str = latex_str.replace(
        "*VHSTART:*", "\\multicolumn{3}{p{0.6\\textwidth}}{"
    ).replace("& *VHEND* & ", "}")

    print(latex_str)

# %% [markdown]
# ## Generate Codebooks

# %%
style_latex(restructure_data(SURVEY_ENTRIES))
# Out:
#                  variable_name  \
# 0                      user_id
# 1                  survey_only
# 2  num_completed_conversations
#
#                                       variable_label variable_category  \
# 0                      Unique participant identifier              meta
# 1  Indicator if participant only completed the su...              meta
# 2  Number of conversations that a participant com...              meta
#
#   variable_type question_text num_missing num_unique  \
# 0     string id             -           0       1500
# 1        binary             -           0          2
# 2           int             -           0          8
#
#                                               values  \
# 0                                         {'-': '-'}
# 1                           {False: 1396, True: 104}
# 2  {'mean': 5.3, 'std': 1.7, 'min': 0.0, 'max': 7.0}
#
#                                                notes
# 0  Pseudonymized from Prolific worker ID. Used to...
# 1
# 2
#           Tag VARIABLE                          LABEL    CATEGORY       TYPE
# 0  0   HEADER  user_id  Unique participant identifier        meta  string id
# 1     OVERALL                                          N Missing:          0
# \fontsize{6pt}{6pt}\selectfont
# \begin{longtable}{p{0.005\textwidth}p{0.20\textwidth}p{0.40\textwidth}p{0.1\textwidth}p{0.1\textwidth}}
# \toprule
#  & VARIABLE & LABEL & CATEGORY & TYPE \\
# \midrule
# \endfirsthead
# \toprule
#  & VARIABLE & LABEL & CATEGORY & TYPE \\
# \midrule
# \endhead
# \midrule
# \multicolumn{5}{r}{Continued on next page} \\
# \midrule
# \endfoot
# \bottomrule
# \endlastfoot
# \bfseries  & \bfseries MIDRULE & \bfseries  & \bfseries  & \bfseries  \\
# \bfseries 0 & \bfseries user\_id & \bfseries Unique participant identifier & \bfseries {\cellcolor{myred}} meta & \bfseries {\cellcolor{myoat}} string id \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 1500 \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: Pseudonymized from Prolific worker ID. Used to link survey data to conversation data. In our paper, we refer to `users' as `participants'. }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 1 & \bfseries survey\_only & \bfseries Indicator if participant only completed the survey, or also completed conversations & \bfseries {\cellcolor{myred}} meta & \bfseries {\cellcolor{myoat}} binary \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 2 \\
#  &  & \multicolumn{2}{r}{False } & 1396 \\
#  &  & \multicolumn{2}{r}{True } & 104 \\
#  \midrule
# \bfseries 2 & \bfseries num\_completed\_conversations & \bfseries Number of conversations that a participant completed & \bfseries {\cellcolor{myred}} meta & \bfseries {\cellcolor{myoat}} int \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 8 \\
#  &  & \multicolumn{2}{r}{mean } & 5.3 \\
#  &  & \multicolumn{2}{r}{std } & 1.7 \\
#  &  & \multicolumn{2}{r}{min } & 0.0 \\
#  &  & \multicolumn{2}{r}{max } & 7.0 \\
#  \midrule
# \bfseries 3 & \bfseries timing\_duration\_s & \bfseries Duration of the survey session (in seconds) & \bfseries {\cellcolor{myred}} meta & \bfseries {\cellcolor{myoat}} float \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 977 \\
#  &  & \multicolumn{2}{r}{mean } & 2154.2 \\
#  &  & \multicolumn{2}{r}{std } & 20557.1 \\
#  &  & \multicolumn{2}{r}{min } & 160.0 \\
#  &  & \multicolumn{2}{r}{max } & 529927.0 \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: Extreme values are caused by participants completing task in multiple sessions. }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 4 & \bfseries timing\_duration\_mins & \bfseries Duration of the survey session (in minutes) & \bfseries {\cellcolor{mygreen}} constructed & \bfseries {\cellcolor{myoat}} float \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 977 \\
#  &  & \multicolumn{2}{r}{mean } & 35.9 \\
#  &  & \multicolumn{2}{r}{std } & 342.6 \\
#  &  & \multicolumn{2}{r}{min } & 2.7 \\
#  &  & \multicolumn{2}{r}{max } & 8832.1 \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: timing\_duration\_s / 60. Extreme values are caused by participants completing task in multiple sessions. }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 5 & \bfseries generated\_datetime & \bfseries Recorded date of the survey completion & \bfseries {\cellcolor{myred}} meta & \bfseries {\cellcolor{myoat}} datetime \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 1492 \\
#  &  & \multicolumn{2}{r}{earliest date } & 2023-11-22 15:48:46 \\
#  &  & \multicolumn{2}{r}{latest\_date } & 2023-12-22 06:56:27 \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: End time, not start time }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 6 & \bfseries consent & \bfseries Participant informed consent confirmation & \bfseries {\cellcolor{myyellow}} direct & \bfseries {\cellcolor{myoat}} categorical \\
#  \midrule
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Question text:} If you have read the information above and agree to participate with the understanding that the data (including any personal data) you submit will be processed accordingly, please select the box below to start. }  \\
#  & \cline{1-4}
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 1 \\
#  &  & \multicolumn{2}{r}{Yes, I consent to take part } & 1500 \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: See full informed consent document for details }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 7 & \bfseries consent\_age & \bfseries Participant age confirmation & \bfseries {\cellcolor{myyellow}} direct & \bfseries {\cellcolor{myoat}} categorical \\
#  \midrule
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Question text:} Please note that you may only participate in this survey if you are 18 years of age or over. }  \\
#  & \cline{1-4}
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 1 \\
#  &  & \multicolumn{2}{r}{I certify that I am 18 years of age or over } & 1500 \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: See full informed consent document for details }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 8 & \bfseries lm\_familiarity & \bfseries Familiarity with LLMs & \bfseries {\cellcolor{myyellow}} direct & \bfseries {\cellcolor{myoat}} categorical \\
#  \midrule
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Question text:} How familiar are you with AI language models like ChatGPT? }  \\
#  & \cline{1-4}
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 3 \\
#  &  & \multicolumn{2}{r}{Somewhat familiar } & 920 \\
#  &  & \multicolumn{2}{r}{Very familiar } & 424 \\
#  &  & \multicolumn{2}{r}{Not familiar at all } & 156 \\
#  \midrule
# \bfseries 9 & \bfseries lm\_direct\_use & \bfseries Direct use of LLMs & \bfseries {\cellcolor{myyellow}} direct & \bfseries {\cellcolor{myoat}} categorical \\
#  \midrule
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Question text:} Have you directly used or communicated with an AI language model, such as asking questions to ChatGPT, BARD, Claude or other similar models? }  \\
#  & \cline{1-4}
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 3 \\
#  &  & \multicolumn{2}{r}{Yes } & 1162 \\
#  &  & \multicolumn{2}{r}{No } & 259 \\
#  &  & \multicolumn{2}{r}{Unsure } & 79 \\
#  \midrule
# \bfseries 10 & \bfseries lm\_indirect\_use & \bfseries Direct use of LLMs & \bfseries {\cellcolor{myyellow}} direct & \bfseries {\cellcolor{myoat}} categorical \\
#  \midrule
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Question text:} Have you directly used or communicated with an AI language model, such as asking questions to ChatGPT, BARD, Claude or other similar models? }  \\
#  & \cline{1-4}
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 3 \\
#  &  & \multicolumn{2}{r}{Yes } & 1104 \\
#  &  & \multicolumn{2}{r}{No } & 215 \\
#  &  & \multicolumn{2}{r}{Unsure } & 181 \\
#  \midrule
# \bfseries 11 & \bfseries lm\_frequency\_use & \bfseries Frequency of using Large Language Models & \bfseries {\cellcolor{myyellow}} direct & \bfseries {\cellcolor{myoat}} categorical \\
#  \midrule
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Question text:} How often do you use or communicate with AI language models? }  \\
#  & \cline{1-4}
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 247 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 5 \\
#  &  & \multicolumn{2}{r}{Once per month } & 374 \\
#  &  & \multicolumn{2}{r}{Every week } & 316 \\
#  &  & \multicolumn{2}{r}{More than once a month } & 291 \\
#  &  & \multicolumn{2}{r}{None } & 247 \\
#  &  & \multicolumn{2}{r}{Less than one a year } & 162 \\
#  &  & \multicolumn{2}{r}{Every day } & 110 \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: Only shown if lm\_indirect\_use==1 OR lm\_direct\_use==1. Null indicates particiant did not see question. }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 12 & \bfseries lm\_usecases & \bfseries Use cases of LLMs & \bfseries {\cellcolor{myyellow}} direct & \bfseries {\cellcolor{myoat}} dict \\
#  \midrule
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Question text:} Which of the following scenarios best describe how and why you use AI language models? Select all that apply. }  \\
#  & \cline{1-4}
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 247 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 853 \\
#  & \cline{1-4}
#  & homework\_assistance & \multicolumn{3}{p{0.6\textwidth}}{Homework Assistance: Getting help with school or university assignments. } \\
#  &  & \multicolumn{2}{r}{False } & 967 \\
#  &  & \multicolumn{2}{r}{True } & 533 \\
#  & \cline{1-4}
#  & research & \multicolumn{3}{p{0.6\textwidth}}{Research: Fact-checking or gaining overviews on specific topics. } \\
#  &  & \multicolumn{2}{r}{True } & 864 \\
#  &  & \multicolumn{2}{r}{False } & 636 \\
#  & \cline{1-4}
#  & source\_suggestions & \multicolumn{3}{p{0.6\textwidth}}{Source Suggestions: Creating or finding bibliographies, information sources or reading lists. } \\
#  &  & \multicolumn{2}{r}{False } & 1036 \\
#  &  & \multicolumn{2}{r}{True } & 464 \\
#  & \cline{1-4}
#  & professional\_work & \multicolumn{3}{p{0.6\textwidth}}{Professional Work: Assisting in drafting, editing, or brainstorming content for work. } \\
#  &  & \multicolumn{2}{r}{False } & 784 \\
#  &  & \multicolumn{2}{r}{True } & 716 \\
#  & \cline{1-4}
#  & creative\_writing & \multicolumn{3}{p{0.6\textwidth}}{Creative Writing: Generating story ideas, dialogues, poems or other writing prompts. } \\
#  &  & \multicolumn{2}{r}{False } & 861 \\
#  &  & \multicolumn{2}{r}{True } & 639 \\
#  & \cline{1-4}
#  & casual\_conversation & \multicolumn{3}{p{0.6\textwidth}}{Casual Conversation: Engaging in small talk, casual chats, or joke generation. } \\
#  &  & \multicolumn{2}{r}{False } & 991 \\
#  &  & \multicolumn{2}{r}{True } & 509 \\
#  & \cline{1-4}
#  & personal\_recommendations & \multicolumn{3}{p{0.6\textwidth}}{Personal Recommendations: Seeking book, music or movie recommendations. } \\
#  &  & \multicolumn{2}{r}{False } & 987 \\
#  &  & \multicolumn{2}{r}{True } & 513 \\
#  & \cline{1-4}
#  & daily\_productivity & \multicolumn{3}{p{0.6\textwidth}}{Daily Productivity: Setting reminders, making to-do lists, or productivity tips. } \\
#  &  & \multicolumn{2}{r}{False } & 1037 \\
#  &  & \multicolumn{2}{r}{True } & 463 \\
#  & \cline{1-4}
#  & technical\_or\_programming\_help & \multicolumn{3}{p{0.6\textwidth}}{Technical or Programming Help: Seeking programming guidance, code generation, software recommendations, or debugging assistance. } \\
#  &  & \multicolumn{2}{r}{False } & 916 \\
#  &  & \multicolumn{2}{r}{True } & 584 \\
#  & \cline{1-4}
#  & travel\_guidance & \multicolumn{3}{p{0.6\textwidth}}{Travel Guidance: Getting destination recommendations, planning holidays, or cultural etiquette tips. } \\
#  &  & \multicolumn{2}{r}{False } & 1120 \\
#  &  & \multicolumn{2}{r}{True } & 380 \\
#  & \cline{1-4}
#  & lifestyle\_and\_hobbies & \multicolumn{3}{p{0.6\textwidth}}{Lifestyle and Hobbies: Looking for recipes, craft ideas, home decoration tips, or hobby-related information. } \\
#  &  & \multicolumn{2}{r}{False } & 943 \\
#  &  & \multicolumn{2}{r}{True } & 557 \\
#  & \cline{1-4}
#  & well-being\_guidance & \multicolumn{3}{p{0.6\textwidth}}{Well-being Guidance: Seeking general exercise routines, wellness or meditation tips. } \\
#  &  & \multicolumn{2}{r}{False } & 1094 \\
#  &  & \multicolumn{2}{r}{True } & 406 \\
#  & \cline{1-4}
#  & medical\_guidance & \multicolumn{3}{p{0.6\textwidth}}{Medical Guidance: Seeking health-related advice or medical guidance. } \\
#  &  & \multicolumn{2}{r}{False } & 1123 \\
#  &  & \multicolumn{2}{r}{True } & 377 \\
#  & \cline{1-4}
#  & financial\_guidance & \multicolumn{3}{p{0.6\textwidth}}{Financial Guidance: Asking about financial concepts or general investing ideas. } \\
#  &  & \multicolumn{2}{r}{False } & 1146 \\
#  &  & \multicolumn{2}{r}{True } & 354 \\
#  & \cline{1-4}
#  & games & \multicolumn{3}{p{0.6\textwidth}}{Games: Playing text-based games, generating riddles or puzzles. } \\
#  &  & \multicolumn{2}{r}{False } & 1110 \\
#  &  & \multicolumn{2}{r}{True } & 390 \\
#  & \cline{1-4}
#  & historical\_or\_news\_insight & \multicolumn{3}{p{0.6\textwidth}}{Historical or News Insight: Getting summaries or background on historical events or news and current affairs. } \\
#  &  & \multicolumn{2}{r}{False } & 1070 \\
#  &  & \multicolumn{2}{r}{True } & 430 \\
#  & \cline{1-4}
#  & relationship\_advice & \multicolumn{3}{p{0.6\textwidth}}{Relationship Advice: Seeking general self-help or relationship advice for family, friends or partners. } \\
#  &  & \multicolumn{2}{r}{False } & 1155 \\
#  &  & \multicolumn{2}{r}{True } & 345 \\
#  & \cline{1-4}
#  & language\_learning & \multicolumn{3}{p{0.6\textwidth}}{Language Learning: Using it as a tool for language practice or translation. } \\
#  &  & \multicolumn{2}{r}{False } & 1024 \\
#  &  & \multicolumn{2}{r}{True } & 476 \\
#  & \cline{1-4}
#  & other & \multicolumn{3}{p{0.6\textwidth}}{Other (selected) } \\
#  &  & \multicolumn{2}{r}{False } & 1129 \\
#  &  & \multicolumn{2}{r}{True } & 371 \\
#  & \cline{1-4}
#  & other\_text & \multicolumn{3}{p{0.6\textwidth}}{Other (typed text) } \\
#  &  & \multicolumn{2}{r}{mean chars } & 45.8 \\
#  &  & \multicolumn{2}{r}{std chars } & 41.9 \\
#  &  & \multicolumn{2}{r}{min chars } & 3.0 \\
#  &  & \multicolumn{2}{r}{max chars } & 328.0 \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: Question only show if lm\_direct\_use==1 OR lm\_indirect\_use==1.
# N Missing indicates the participants who have at least one missing value in the usecases (besides from 'other\_text').
# N Unique indicates the unique combinations of use cases selected by participants.
# On 'other\_text', Null indicates participant did not type anything.
# On all other keys, 0 indicates participant saw question and did not select usecase. Null indicates participant did not see question. }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 13 & \bfseries order\_lm\_usecases & \bfseries Use cases of LLMs (order of options presented in survey) & \bfseries {\cellcolor{myred}} meta & \bfseries {\cellcolor{myoat}} dict \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 247 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 1254 \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: Integer 1-18 indicating random order that usecase option was presented to participant.
# For 'other', option is always shown last so will always be 19.
# Null indicates participant did not see question.
# The usecases as the same as in lm\_usecases. }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 14 & \bfseries stated\_prefs & \bfseries Stated preferences over LLM behaviours & \bfseries {\cellcolor{myyellow}} direct & \bfseries {\cellcolor{myoat}} dict \\
#  \midrule
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Question text:} Rate each of the following statements about your opinion on the importance of different AI language model behaviors or traits.
# It is important that an AI language model... }  \\
#  & \cline{1-4}
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 1475 \\
#  & \cline{1-4}
#  & values & \multicolumn{3}{p{0.6\textwidth}}{...reflects my values or cultural perspectives } \\
#  &  & \multicolumn{2}{r}{mean } & 54.3 \\
#  &  & \multicolumn{2}{r}{std } & 26.3 \\
#  &  & \multicolumn{2}{r}{min } & 0.0 \\
#  &  & \multicolumn{2}{r}{max } & 100.0 \\
#  & \cline{1-4}
#  & creativity & \multicolumn{3}{p{0.6\textwidth}}{...produces responses that are creative and inspiring } \\
#  &  & \multicolumn{2}{r}{mean } & 69.6 \\
#  &  & \multicolumn{2}{r}{std } & 22.1 \\
#  &  & \multicolumn{2}{r}{min } & 0.0 \\
#  &  & \multicolumn{2}{r}{max } & 100.0 \\
#  & \cline{1-4}
#  & fluency & \multicolumn{3}{p{0.6\textwidth}}{...produces responses that are well-written and coherent } \\
#  &  & \multicolumn{2}{r}{mean } & 86.7 \\
#  &  & \multicolumn{2}{r}{std } & 16.3 \\
#  &  & \multicolumn{2}{r}{min } & 2.0 \\
#  &  & \multicolumn{2}{r}{max } & 100.0 \\
#  & \cline{1-4}
#  & factuality & \multicolumn{3}{p{0.6\textwidth}}{...produces factual and informative responses } \\
#  &  & \multicolumn{2}{r}{mean } & 88.7 \\
#  &  & \multicolumn{2}{r}{std } & 16.2 \\
#  &  & \multicolumn{2}{r}{min } & 0.0 \\
#  &  & \multicolumn{2}{r}{max } & 100.0 \\
#  & \cline{1-4}
#  & diversity & \multicolumn{3}{p{0.6\textwidth}}{...summarises multiple viewpoints or different worldviews } \\
#  &  & \multicolumn{2}{r}{mean } & 75.7 \\
#  &  & \multicolumn{2}{r}{std } & 20.0 \\
#  &  & \multicolumn{2}{r}{min } & 0.0 \\
#  &  & \multicolumn{2}{r}{max } & 100.0 \\
#  & \cline{1-4}
#  & safety & \multicolumn{3}{p{0.6\textwidth}}{...produces responses that are safe and do not risk harm to myself and others } \\
#  &  & \multicolumn{2}{r}{mean } & 80.2 \\
#  &  & \multicolumn{2}{r}{std } & 25.2 \\
#  &  & \multicolumn{2}{r}{min } & 0.0 \\
#  &  & \multicolumn{2}{r}{max } & 100.0 \\
#  & \cline{1-4}
#  & personalisation & \multicolumn{3}{p{0.6\textwidth}}{...learns from our conversations and feels personalised to me } \\
#  &  & \multicolumn{2}{r}{mean } & 67.9 \\
#  &  & \multicolumn{2}{r}{std } & 24.6 \\
#  &  & \multicolumn{2}{r}{min } & 0.0 \\
#  &  & \multicolumn{2}{r}{max } & 100.0 \\
#  & \cline{1-4}
#  & helpfulness & \multicolumn{3}{p{0.6\textwidth}}{...produces responses that are helpful and relevant to my requests } \\
#  &  & \multicolumn{2}{r}{mean } & 89.4 \\
#  &  & \multicolumn{2}{r}{std } & 14.4 \\
#  &  & \multicolumn{2}{r}{min } & 0.0 \\
#  &  & \multicolumn{2}{r}{max } & 100.0 \\
#  & \cline{1-4}
#  & other & \multicolumn{3}{p{0.6\textwidth}}{Other (selected) } \\
#  &  & \multicolumn{2}{r}{mean } & 57.5 \\
#  &  & \multicolumn{2}{r}{std } & 19.0 \\
#  &  & \multicolumn{2}{r}{min } & 0.0 \\
#  &  & \multicolumn{2}{r}{max } & 100.0 \\
#  & \cline{1-4}
#  & other\_text & \multicolumn{3}{p{0.6\textwidth}}{Other (typed text) } \\
#  &  & \multicolumn{2}{r}{mean chars } & 32.6 \\
#  &  & \multicolumn{2}{r}{std chars } & 24.4 \\
#  &  & \multicolumn{2}{r}{min chars } & 1.0 \\
#  &  & \multicolumn{2}{r}{max chars } & 144.0 \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: Sliders from [Strongly disagree] to [Strongly agree] are recorded on a 0-100 scale. Participant does not see numeric value.
# N Missing indicates the participants who have at least one missing value in the attributes (besides from 'other\_text').
# N Unique indicates the unique combinations of use cases selected by participants.
# On 'other\_text', Null indicates participant did not type anything.
# Note that this scale (on Qualtrics) runs 0-100. The Conversations rating scales (for choice\_attributes, performance\_attributes on Dynabench) run 1-100.
#  }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 15 & \bfseries order\_stated\_prefs & \bfseries Stated preferences over LLM behaviours (order of options presented in survey) & \bfseries {\cellcolor{myred}} meta & \bfseries {\cellcolor{myoat}} dict \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 1467 \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: Integer 1-8 indicating random order that attribute slider was presented to participant.
# For 'other', option is always shown last so will always be 9.
# Null indicates participant did not see question.
# The attributes as the same as in stated\_prefs. }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 16 & \bfseries self\_description & \bfseries Participant self-written profile describing themself & \bfseries {\cellcolor{myyellow}} direct & \bfseries {\cellcolor{myoat}} string \\
#  \midrule
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Question text:} Please briefly describe your values, core beliefs, guiding principles in life, or other things that are important to you. For example, you might include values you'd want to teach to your children or qualities you look for in friends. There are no right or wrong answers. Please do not provide any personally identifiable details like your name, address or email. Please write 2-5 sentences in your own words. }  \\
#  & \cline{1-4}
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 1500 \\
#  &  & \multicolumn{2}{r}{mean chars } & 241.3 \\
#  &  & \multicolumn{2}{r}{std chars } & 134.6 \\
#  &  & \multicolumn{2}{r}{min chars } & 3.0 \\
#  &  & \multicolumn{2}{r}{max chars } & 1547.0 \\
#  \midrule
# \bfseries 17 & \bfseries system\_string & \bfseries Participant self-written system string, constitution or custom instructions for an LLM & \bfseries {\cellcolor{myyellow}} direct & \bfseries {\cellcolor{myoat}} string \\
#  \midrule
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Question text:} Imagine you are instructing an AI language model how to behave. You can think of this like a set of core principles that the AI language model will always try to follow, no matter what task you ask it to perform. In your own words, describe what characteristics, personality traits or features you believe the AI should consistently exhibit. You can also instruct the model what behaviours or content you don't want to see. If you envision the AI behaving differently in various contexts (e.g., professional assistance vs. storytelling), please specify the general adaptations you'd like to see. Please write 2-5 sentences in your own words. }  \\
#  & \cline{1-4}
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 1500 \\
#  &  & \multicolumn{2}{r}{mean chars } & 260.4 \\
#  &  & \multicolumn{2}{r}{std chars } & 288.4 \\
#  &  & \multicolumn{2}{r}{min chars } & 16.0 \\
#  &  & \multicolumn{2}{r}{max chars } & 9530.0 \\
#  \midrule
# \bfseries 18 & \bfseries age & \bfseries Age & \bfseries {\cellcolor{myyellow}} direct & \bfseries {\cellcolor{myoat}} categorical \\
#  \midrule
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Question text:} How old are you? }  \\
#  & \cline{1-4}
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 7 \\
#  &  & \multicolumn{2}{r}{25-34 years old } & 454 \\
#  &  & \multicolumn{2}{r}{18-24 years old } & 297 \\
#  &  & \multicolumn{2}{r}{35-44 years old } & 237 \\
#  &  & \multicolumn{2}{r}{45-54 years old } & 208 \\
#  &  & \multicolumn{2}{r}{55-64 years old } & 197 \\
#  &  & \multicolumn{2}{r}{65+ years old } & 106 \\
#  &  & \multicolumn{2}{r}{Prefer not to say } & 1 \\
#  \midrule
# \bfseries 19 & \bfseries education & \bfseries Education & \bfseries {\cellcolor{myyellow}} direct & \bfseries {\cellcolor{myoat}} categorical \\
#  \midrule
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Question text:} What is the highest level of education you have completed? }  \\
#  & \cline{1-4}
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 9 \\
#  &  & \multicolumn{2}{r}{University Bachelors Degree } & 637 \\
#  &  & \multicolumn{2}{r}{Graduate / Professional degree } & 241 \\
#  &  & \multicolumn{2}{r}{Some University but no degree } & 236 \\
#  &  & \multicolumn{2}{r}{Completed Secondary School } & 209 \\
#  &  & \multicolumn{2}{r}{Vocational } & 125 \\
#  &  & \multicolumn{2}{r}{Some Secondary } & 24 \\
#  &  & \multicolumn{2}{r}{Completed Primary School } & 16 \\
#  &  & \multicolumn{2}{r}{Prefer not to say } & 9 \\
#  &  & \multicolumn{2}{r}{Some Primary } & 3 \\
#  \midrule
# \bfseries 20 & \bfseries employment\_status & \bfseries Employment Status & \bfseries {\cellcolor{myyellow}} direct & \bfseries {\cellcolor{myoat}} categorical \\
#  \midrule
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Question text:} What best describes your employment status over the last three months? }  \\
#  & \cline{1-4}
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 8 \\
#  &  & \multicolumn{2}{r}{Working full-time } & 712 \\
#  &  & \multicolumn{2}{r}{Working part-time } & 265 \\
#  &  & \multicolumn{2}{r}{Student } & 191 \\
#  &  & \multicolumn{2}{r}{Unemployed, seeking work } & 113 \\
#  &  & \multicolumn{2}{r}{Retired } & 104 \\
#  &  & \multicolumn{2}{r}{Homemaker / Stay-at-home parent } & 46 \\
#  &  & \multicolumn{2}{r}{Unemployed, not seeking work } & 46 \\
#  &  & \multicolumn{2}{r}{Prefer not to say } & 23 \\
#  \midrule
# \bfseries 21 & \bfseries marital\_status & \bfseries Marital Status & \bfseries {\cellcolor{myyellow}} direct & \bfseries {\cellcolor{myoat}} categorical \\
#  \midrule
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Question text:} What is your current marital status? }  \\
#  & \cline{1-4}
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 5 \\
#  &  & \multicolumn{2}{r}{Never been married } & 870 \\
#  &  & \multicolumn{2}{r}{Married } & 463 \\
#  &  & \multicolumn{2}{r}{Divorced / Separated } & 123 \\
#  &  & \multicolumn{2}{r}{Prefer not to say } & 23 \\
#  &  & \multicolumn{2}{r}{Widowed } & 21 \\
#  \midrule
# \bfseries 22 & \bfseries english\_proficiency & \bfseries English Proficiency & \bfseries {\cellcolor{myyellow}} direct & \bfseries {\cellcolor{myoat}} categorical \\
#  \midrule
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Question text:} How would you describe your proficiency in English? }  \\
#  & \cline{1-4}
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 5 \\
#  &  & \multicolumn{2}{r}{Native speaker } & 886 \\
#  &  & \multicolumn{2}{r}{Fluent } & 405 \\
#  &  & \multicolumn{2}{r}{Advanced } & 160 \\
#  &  & \multicolumn{2}{r}{Intermediate } & 42 \\
#  &  & \multicolumn{2}{r}{Basic } & 7 \\
#  \midrule
# \bfseries 23 & \bfseries gender & \bfseries Gender & \bfseries {\cellcolor{mygreen}} constructed & \bfseries {\cellcolor{myoat}} categorical \\
#  \midrule
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Question text:} How would you describe your proficiency in English? }  \\
#  & \cline{1-4}
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 4 \\
#  &  & \multicolumn{2}{r}{Male } & 757 \\
#  &  & \multicolumn{2}{r}{Female } & 718 \\
#  &  & \multicolumn{2}{r}{Non-binary / third gender } & 21 \\
#  &  & \multicolumn{2}{r}{Prefer not to say } & 4 \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: Participants could chose Male, Female, Non-binary / third Gender, Prefer not to say, or write in their own response. Two independent annotators then categorised the self-describe responses only when abundantly clear they fit another category. See paper for details. }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 24 & \bfseries religion & \bfseries Dictionary of religion information. & \bfseries NA & \bfseries {\cellcolor{myoat}} dict \\
#  \midrule
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: Keys explained below. }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 25 & \bfseries religion\_self\_described & \bfseries Participant \{c\} self-description & \bfseries {\cellcolor{myyellow}} direct & \bfseries {\cellcolor{myoat}} string \\
#  \midrule
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Question text:} What is your religious affiliation? }  \\
#  & \cline{1-4}
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 137 \\
#  &  & \multicolumn{2}{r}{mean chars } & 12.2 \\
#  &  & \multicolumn{2}{r}{std chars } & 5.7 \\
#  &  & \multicolumn{2}{r}{min chars } & 2.0 \\
#  &  & \multicolumn{2}{r}{max chars } & 112.0 \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: Participant had option to type and Self Describe or select Prefer not to say. }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 26 & \bfseries religion\_categorised & \bfseries Granular categories of participant religion & \bfseries {\cellcolor{mygreen}} constructed & \bfseries {\cellcolor{myoat}} categorical \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 12 \\
#  &  & \multicolumn{2}{r}{Non-religious } & 762 \\
#  &  & \multicolumn{2}{r}{Christian } & 487 \\
#  &  & \multicolumn{2}{r}{Agnostic } & 71 \\
#  &  & \multicolumn{2}{r}{Prefer not to say } & 59 \\
#  &  & \multicolumn{2}{r}{Jewish } & 42 \\
#  &  & \multicolumn{2}{r}{Muslim } & 31 \\
#  &  & \multicolumn{2}{r}{Spiritual } & 18 \\
#  &  & \multicolumn{2}{r}{Buddhist } & 12 \\
#  &  & \multicolumn{2}{r}{Folk religion } & 6 \\
#  &  & \multicolumn{2}{r}{Hindu } & 5 \\
#  &  & \multicolumn{2}{r}{Other } & 4 \\
#  &  & \multicolumn{2}{r}{Sikh } & 3 \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: Two independent annotators manually verified all automated classifications (gpt-4-turbo) of the self-describe string. See paper for details. }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 27 & \bfseries religion\_simplified & \bfseries Simplified categories of participant religion & \bfseries {\cellcolor{mygreen}} constructed & \bfseries {\cellcolor{myoat}} categorical \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 6 \\
#  &  & \multicolumn{2}{r}{No Affiliation } & 851 \\
#  &  & \multicolumn{2}{r}{Christian } & 487 \\
#  &  & \multicolumn{2}{r}{Prefer not to say } & 59 \\
#  &  & \multicolumn{2}{r}{Jewish } & 42 \\
#  &  & \multicolumn{2}{r}{Muslim } & 31 \\
#  &  & \multicolumn{2}{r}{Other } & 30 \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: Simplified version of religion\_categorised for more aggregate analysis. }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 28 & \bfseries ethnicity & \bfseries Dictionary of ethnicity information. & \bfseries NA & \bfseries {\cellcolor{myoat}} dict \\
#  \midrule
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: Keys explained below. }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 29 & \bfseries ethnicity\_self\_described & \bfseries Participant \{c\} self-description & \bfseries {\cellcolor{myyellow}} direct & \bfseries {\cellcolor{myoat}} string \\
#  \midrule
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Question text:} What is your ethnicity? }  \\
#  & \cline{1-4}
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 264 \\
#  &  & \multicolumn{2}{r}{mean chars } & 9.2 \\
#  &  & \multicolumn{2}{r}{std chars } & 6.2 \\
#  &  & \multicolumn{2}{r}{min chars } & 3.0 \\
#  &  & \multicolumn{2}{r}{max chars } & 99.0 \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: Participant had option to type and Self Describe or select Prefer not to say. }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 30 & \bfseries ethnicity\_categorised & \bfseries Granular categories of participant ethnicity & \bfseries {\cellcolor{mygreen}} constructed & \bfseries {\cellcolor{myoat}} categorical \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 9 \\
#  &  & \multicolumn{2}{r}{White } & 969 \\
#  &  & \multicolumn{2}{r}{Black / African } & 122 \\
#  &  & \multicolumn{2}{r}{Hispanic / Latino } & 121 \\
#  &  & \multicolumn{2}{r}{Asian } & 95 \\
#  &  & \multicolumn{2}{r}{Prefer not to say } & 86 \\
#  &  & \multicolumn{2}{r}{Mixed } & 68 \\
#  &  & \multicolumn{2}{r}{Other } & 17 \\
#  &  & \multicolumn{2}{r}{Middle Eastern / Arab } & 14 \\
#  &  & \multicolumn{2}{r}{Indigenous / First Peoples } & 8 \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: Two independent annotators manually verified all automated classifications (gpt-4-turbo) of the self-describe string. See paper for details. }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 31 & \bfseries ethnicity\_simplified & \bfseries Simplified categories of participant ethnicity & \bfseries {\cellcolor{mygreen}} constructed & \bfseries {\cellcolor{myoat}} categorical \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 7 \\
#  &  & \multicolumn{2}{r}{White } & 969 \\
#  &  & \multicolumn{2}{r}{Black } & 122 \\
#  &  & \multicolumn{2}{r}{Hispanic } & 121 \\
#  &  & \multicolumn{2}{r}{Asian } & 95 \\
#  &  & \multicolumn{2}{r}{Prefer not to say } & 86 \\
#  &  & \multicolumn{2}{r}{Mixed } & 68 \\
#  &  & \multicolumn{2}{r}{Other } & 39 \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: Simplified version of ethnicity\_categorised for more aggregate analysis. }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 32 & \bfseries location & \bfseries Dictionary of location information. & \bfseries NA & \bfseries {\cellcolor{myoat}} dict \\
#  \midrule
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: Keys explained below. }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 33 & \bfseries location\_birth\_country & \bfseries Participant country of birth & \bfseries {\cellcolor{myyellow}} direct & \bfseries {\cellcolor{myoat}} categorical \\
#  \midrule
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Question text:} In which country were you born? }  \\
#  & \cline{1-4}
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 75 \\
#  &  & \multicolumn{2}{r}{Too many values to show } & - \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: Selected from standardised dropdown country list. }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 34 & \bfseries location\_birth\_countryISO & \bfseries ISO 3166-1 alpha-3 code for the country of birth & \bfseries {\cellcolor{mygreen}} constructed & \bfseries {\cellcolor{myoat}} categorical \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 75 \\
#  &  & \multicolumn{2}{r}{Too many values to show } & - \\
#  \midrule
# \bfseries 35 & \bfseries location\_birth\_subregion & \bfseries Participant sub-region of birth & \bfseries {\cellcolor{mygreen}} constructed & \bfseries {\cellcolor{myoat}} categorical \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 16 \\
#  &  & \multicolumn{2}{r}{Too many values to show } & - \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: Mapped from country of birth, based on United Nations defined subregions. }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 36 & \bfseries location\_reside\_country & \bfseries Participant country of residence & \bfseries {\cellcolor{myyellow}} direct & \bfseries {\cellcolor{myoat}} categorical \\
#  \midrule
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Question text:} In which country do you currently reside? }  \\
#  & \cline{1-4}
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 38 \\
#  &  & \multicolumn{2}{r}{Too many values to show } & - \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: Selected from standardised dropdown country list. }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 37 & \bfseries location\_reside\_countryISO & \bfseries ISO 3166-1 alpha-3 code for the country of residence & \bfseries {\cellcolor{mygreen}} constructed & \bfseries {\cellcolor{myoat}} categorical \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 38 \\
#  &  & \multicolumn{2}{r}{Too many values to show } & - \\
#  \midrule
# \bfseries 38 & \bfseries location\_reside\_subregion & \bfseries Participant sub-region of residence & \bfseries {\cellcolor{mygreen}} constructed & \bfseries {\cellcolor{myoat}} categorical \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 11 \\
#  &  & \multicolumn{2}{r}{Too many values to show } & - \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: Mapped from country of residence, based on United Nations defined subregions. }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 39 & \bfseries location\_same\_birth\_reside\_country & \bfseries Whether the participant was born and resides in the same country & \bfseries {\cellcolor{mygreen}} constructed & \bfseries {\cellcolor{myoat}} binary \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 3 \\
#  &  & \multicolumn{2}{r}{Yes } & 1320 \\
#  &  & \multicolumn{2}{r}{No } & 177 \\
#  &  & \multicolumn{2}{r}{Prefer not to say } & 3 \\
#  \midrule
# \bfseries 40 & \bfseries location\_special\_region & \bfseries Adjusted regional categories for unique sample properties & \bfseries {\cellcolor{mygreen}} constructed & \bfseries {\cellcolor{myoat}} categorical \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 11 \\
#  &  & \multicolumn{2}{r}{US } & 338 \\
#  &  & \multicolumn{2}{r}{Europe } & 313 \\
#  &  & \multicolumn{2}{r}{UK } & 292 \\
#  &  & \multicolumn{2}{r}{Latin America and the Caribbean } & 146 \\
#  &  & \multicolumn{2}{r}{Australia and New Zealand } & 129 \\
#  &  & \multicolumn{2}{r}{Africa } & 118 \\
#  &  & \multicolumn{2}{r}{Asia } & 60 \\
#  &  & \multicolumn{2}{r}{Northern America } & 50 \\
#  &  & \multicolumn{2}{r}{Middle East } & 50 \\
#  &  & \multicolumn{2}{r}{Prefer not to say } & 3 \\
#  &  & \multicolumn{2}{r}{Oceania } & 1 \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: Within regions and sub-regions, some countries are split out to better represent sample density (e.g., treating UK and US samples seperately from Europe and North America). }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 41 & \bfseries study\_id & \bfseries Unique study idenfitier on Prolific & \bfseries {\cellcolor{myred}} meta & \bfseries {\cellcolor{myoat}} string id \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 51 \\
#  \midrule
# \bfseries 42 & \bfseries study\_locale & \bfseries Recruitment country of Prolific study & \bfseries {\cellcolor{myred}} meta & \bfseries {\cellcolor{myoat}} categorical \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 33 \\
#  &  & \multicolumn{2}{r}{Too many values to show } & - \\
#  \midrule
# \bfseries 43 & \bfseries included\_in\_UK\_REP & \bfseries Indicator if participant was included in the rebalanced UK representative sample & \bfseries {\cellcolor{mygreen}} constructed & \bfseries {\cellcolor{myoat}} binary \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 2 \\
#  &  & \multicolumn{2}{r}{False } & 1257 \\
#  &  & \multicolumn{2}{r}{True } & 243 \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: Census-representative samples were rebalanced to mitigate sampling issues. See paper for details. }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 44 & \bfseries included\_in\_US\_REP & \bfseries Indicator if participant was included in the rebalanced US representative sample & \bfseries {\cellcolor{mygreen}} constructed & \bfseries {\cellcolor{myoat}} binary \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 2 \\
#  &  & \multicolumn{2}{r}{False } & 1270 \\
#  &  & \multicolumn{2}{r}{True } & 230 \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: Census-representative samples were rebalanced to mitigate sampling issues. See paper for details. }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 45 & \bfseries included\_in\_balanced\_subset & \bfseries Indicator if participant's conversations are included in the balanced subset & \bfseries {\cellcolor{mygreen}} constructed & \bfseries {\cellcolor{myoat}} binary \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 2 \\
#  &  & \multicolumn{2}{r}{True } & 1246 \\
#  &  & \multicolumn{2}{r}{False } & 254 \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: Balanced subset was created to equally sample conversations of three types (unguided, values, controversy).
# We only include participants who have at least one of each conversation type, and then ensure equal numbers of each type are retained.
# See paper for details. }}  \\
#  & \cline{1-4}
# \end{longtable}

# %%
style_latex(restructure_data(CONVO_ENTRIES))
# Out:
#                  variable_name  \
# 0                      user_id
# 1              conversation_id
# 2  included_in_balanced_subset
#
#                                       variable_label variable_category  \
# 0                      Unique participant identifier              meta
# 1                     Unique conversation identifier              meta
# 2  Indicator if participant's conversations are i...       constructed
#
#   variable_type question_text num_missing num_unique  \
# 0     string id             -           0       1396
# 1     string id             -           0       8011
# 2        binary             -           0          2
#
#                       values  \
# 0                 {'-': '-'}
# 1                 {'-': '-'}
# 2  {True: 6696, False: 1315}
#
#                                                notes
# 0  Pseudonymized from Prolific worker ID. Used to...
# 1
# 2  Balanced subset was created to equally sample ...
#           Tag VARIABLE                          LABEL    CATEGORY       TYPE
# 0  0   HEADER  user_id  Unique participant identifier        meta  string id
# 1     OVERALL                                          N Missing:          0
# \fontsize{6pt}{6pt}\selectfont
# \begin{longtable}{p{0.005\textwidth}p{0.20\textwidth}p{0.40\textwidth}p{0.1\textwidth}p{0.1\textwidth}}
# \toprule
#  & VARIABLE & LABEL & CATEGORY & TYPE \\
# \midrule
# \endfirsthead
# \toprule
#  & VARIABLE & LABEL & CATEGORY & TYPE \\
# \midrule
# \endhead
# \midrule
# \multicolumn{5}{r}{Continued on next page} \\
# \midrule
# \endfoot
# \bottomrule
# \endlastfoot
# \bfseries  & \bfseries MIDRULE & \bfseries  & \bfseries  & \bfseries  \\
# \bfseries 0 & \bfseries user\_id & \bfseries Unique participant identifier & \bfseries {\cellcolor{myred}} meta & \bfseries {\cellcolor{myoat}} string id \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 1396 \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: Pseudonymized from Prolific worker ID. Used to link conversation data to survey data. }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 1 & \bfseries conversation\_id & \bfseries Unique conversation identifier & \bfseries {\cellcolor{myred}} meta & \bfseries {\cellcolor{myoat}} string id \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 8011 \\
#  \midrule
# \bfseries 2 & \bfseries included\_in\_balanced\_subset & \bfseries Indicator if participant's conversations are included in the balanced subset & \bfseries {\cellcolor{mygreen}} constructed & \bfseries {\cellcolor{myoat}} binary \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 2 \\
#  &  & \multicolumn{2}{r}{True } & 6696 \\
#  &  & \multicolumn{2}{r}{False } & 1315 \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: Balanced subset was created to equally sample conversations of three types (unguided, values, controversy).
# We only include participants who have at least one of each conversation type, and then ensure equal numbers of each type are retained.
# See paper for details. }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 3 & \bfseries timing\_duration\_s & \bfseries Duration of the conversation (in seconds) & \bfseries {\cellcolor{myred}} meta & \bfseries {\cellcolor{myoat}} float \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 7656 \\
#  &  & \multicolumn{2}{r}{mean } & 555.9 \\
#  &  & \multicolumn{2}{r}{std } & 422.1 \\
#  &  & \multicolumn{2}{r}{min } & 73.5 \\
#  &  & \multicolumn{2}{r}{max } & 17145.8 \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: Extreme values are caused by participants completing task in multiple sessions. }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 4 & \bfseries timing\_duration\_mins & \bfseries Duration of the conversation (in minutes) & \bfseries {\cellcolor{mygreen}} constructed & \bfseries {\cellcolor{myoat}} float \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 1948 \\
#  &  & \multicolumn{2}{r}{mean } & 9.3 \\
#  &  & \multicolumn{2}{r}{std } & 7.0 \\
#  &  & \multicolumn{2}{r}{min } & 1.2 \\
#  &  & \multicolumn{2}{r}{max } & 285.8 \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: timing\_duration\_s / 60. Extreme values are caused by participants completing task in multiple sessions. }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 5 & \bfseries generated\_datetime & \bfseries Recorded date of the conversation completion & \bfseries {\cellcolor{myred}} meta & \bfseries {\cellcolor{myoat}} datetime \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 7820 \\
#  &  & \multicolumn{2}{r}{earliest date } & 2023-11-22 15:55:46 \\
#  &  & \multicolumn{2}{r}{latest\_date } & 2023-12-22 08:04:46 \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: Recorded at end of conversation, before fine-grained feedback page shown. }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 6 & \bfseries opening\_prompt & \bfseries Opening human-written prompt of the conversation & \bfseries {\cellcolor{myyellow}} direct & \bfseries {\cellcolor{myoat}} string \\
#  \midrule
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Question text:} Now start the conversation with your question, request or statement. }  \\
#  & \cline{1-4}
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 7811 \\
#  &  & \multicolumn{2}{r}{mean chars } & 65.7 \\
#  &  & \multicolumn{2}{r}{std chars } & 59.2 \\
#  &  & \multicolumn{2}{r}{min chars } & 2.0 \\
#  &  & \multicolumn{2}{r}{max chars } & 1195.0 \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: We provide the following soft guidance:
# Need some inspiration? You can request help with a task (like writing a recipe, organising an activity or event, completing an assignment)... You can chitchat, have casual conversation or seek personal advice. You can ask questions about the world, current events or your viewpoints. }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 7 & \bfseries open\_feedback & \bfseries Participant written feedback on the conversation as a whole. & \bfseries {\cellcolor{myyellow}} direct & \bfseries {\cellcolor{myoat}} string \\
#  \midrule
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Question text:} Give the model some feedback on the conversation as whole. Hypothetically, what would an ideal interaction for you look like here? What was good and what was bad? What (if anything) was missing? What would you change to make the conversation better?
# Please write 2-5 sentences in your own words. }  \\
#  & \cline{1-4}
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 7953 \\
#  &  & \multicolumn{2}{r}{mean chars } & 160.1 \\
#  &  & \multicolumn{2}{r}{std chars } & 106.4 \\
#  &  & \multicolumn{2}{r}{min chars } & 2.0 \\
#  &  & \multicolumn{2}{r}{max chars } & 1581.0 \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: Entry box reads: Enter text here. Do not copy and paste. }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 8 & \bfseries conversation\_type & \bfseries Type of conversation (from pre-defined categories) & \bfseries {\cellcolor{myyellow}} direct & \bfseries {\cellcolor{myoat}} categorical \\
#  \midrule
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Question text:} Choose what type of conversation you want to have. }  \\
#  & \cline{1-4}
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 3 \\
#  &  & \multicolumn{2}{r}{unguided } & 3113 \\
#  &  & \multicolumn{2}{r}{values guided } & 2460 \\
#  &  & \multicolumn{2}{r}{controversy guided } & 2438 \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: Participants pick from the following radio buttons:
# Unguided. Ask, request or talk to the model about anything . It is up to you!
# Values guided. Ask, request or talk to the model about something important to you or that represents your values. This could be related to work, religion, family and relationship, politics or culture.
# Controversy guided. Ask, request or talk to the model about something controversial or where people would disagree in your community, culture or country.
# We also provide the additional instruction: Remember if you are here as a paid study participant, you need to do two of each type. If you are here as a volunteer, then take your pick!
#  }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 9 & \bfseries conversation\_turns & \bfseries Number of human-model turns (back-and-forths) in the conversation. & \bfseries {\cellcolor{myred}} meta & \bfseries {\cellcolor{myoat}} int \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 13 \\
#  &  & \multicolumn{2}{r}{mean } & 3.4 \\
#  &  & \multicolumn{2}{r}{std } & 1.6 \\
#  &  & \multicolumn{2}{r}{min } & 2.0 \\
#  &  & \multicolumn{2}{r}{max } & 22.0 \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: We force 2 turns as the minimum. After the opening turn, we give the instruction:
# Now continue the conversation. Conversations can be between 2 and 10 turns. Try to vary the length. When you're done, click Finish. }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 10 & \bfseries conversation\_history & \bfseries Full conversation history (human and model messages, with scores and model metadata) & \bfseries {\cellcolor{myyellow}} direct & \bfseries {\cellcolor{myoat}} dict \\
#  \midrule
#  &  & \multicolumn{2}{r}{Too many values to show } & - \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: We provide an example of what this nested conversation history looks like below. }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 11 & \bfseries performance\_attributes & \bfseries How well the top-rated model response performed across different attributes & \bfseries nested & \bfseries {\cellcolor{myoat}} dict \\
#  \midrule
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Question text:} Tell us how the model performed. Consider your first message and the top-rated response.
# Rate the following statements about the performance across different attributes.
# This response... }  \\
#  & \cline{1-4}
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 1824 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 7532 \\
#  & \cline{1-4}
#  & values & \multicolumn{3}{p{0.6\textwidth}}{...reflected my values or cultural perspective } \\
#  &  & \multicolumn{2}{r}{mean } & 74.1 \\
#  &  & \multicolumn{2}{r}{std } & 22.2 \\
#  &  & \multicolumn{2}{r}{min } & 1.0 \\
#  &  & \multicolumn{2}{r}{max } & 100.0 \\
#  & \cline{1-4}
#  & fluency & \multicolumn{3}{p{0.6\textwidth}}{...was well-written and coherent } \\
#  &  & \multicolumn{2}{r}{mean } & 84.3 \\
#  &  & \multicolumn{2}{r}{std } & 18.3 \\
#  &  & \multicolumn{2}{r}{min } & 1.0 \\
#  &  & \multicolumn{2}{r}{max } & 100.0 \\
#  & \cline{1-4}
#  & factuality & \multicolumn{3}{p{0.6\textwidth}}{...was factual and informative } \\
#  &  & \multicolumn{2}{r}{mean } & 79.2 \\
#  &  & \multicolumn{2}{r}{std } & 21.5 \\
#  &  & \multicolumn{2}{r}{min } & 1.0 \\
#  &  & \multicolumn{2}{r}{max } & 100.0 \\
#  & \cline{1-4}
#  & safety & \multicolumn{3}{p{0.6\textwidth}}{...was safe and doesn't risk harm to myself and others } \\
#  &  & \multicolumn{2}{r}{mean } & 85.1 \\
#  &  & \multicolumn{2}{r}{std } & 19.3 \\
#  &  & \multicolumn{2}{r}{min } & 1.0 \\
#  &  & \multicolumn{2}{r}{max } & 100.0 \\
#  & \cline{1-4}
#  & diversity & \multicolumn{3}{p{0.6\textwidth}}{...summarised multiple viewpoints or different worldviews } \\
#  &  & \multicolumn{2}{r}{mean } & 68.7 \\
#  &  & \multicolumn{2}{r}{std } & 25.3 \\
#  &  & \multicolumn{2}{r}{min } & 1.0 \\
#  &  & \multicolumn{2}{r}{max } & 100.0 \\
#  & \cline{1-4}
#  & creativity & \multicolumn{3}{p{0.6\textwidth}}{...was creative and inspiring } \\
#  &  & \multicolumn{2}{r}{mean } & 63.7 \\
#  &  & \multicolumn{2}{r}{std } & 26.1 \\
#  &  & \multicolumn{2}{r}{min } & 1.0 \\
#  &  & \multicolumn{2}{r}{max } & 100.0 \\
#  & \cline{1-4}
#  & helpfulness & \multicolumn{3}{p{0.6\textwidth}}{...was helpful and relevant to my request } \\
#  &  & \multicolumn{2}{r}{mean } & 81.5 \\
#  &  & \multicolumn{2}{r}{std } & 21.9 \\
#  &  & \multicolumn{2}{r}{min } & 1.0 \\
#  &  & \multicolumn{2}{r}{max } & 100.0 \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: Sliders from [Performed very poorly] to [Performed very well] are recorded on a 1-100 scale. Participant does not see numeric value.
# Note that the attributes align choice\_attributes, as well as with the stated preference ratings from The Survey.
# Participants had option to select N/A, which is recorded as Null.
# N Missing indicates the number of participants who have at least one missing value in the nested columns.
# N Unique indicates the unique combinations of use cases selected by participants.
# There was no option for 'other'.
# Note, these sliders run from 1-100 (on Dynabench). The sliders for stated\_prefs (in Survey on Qualtrics) run 0-100. }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 12 & \bfseries choice\_attributes & \bfseries How different attributes influenced the participant's choice of the top-rated model response & \bfseries {\cellcolor{myyellow}} direct & \bfseries {\cellcolor{myoat}} dict \\
#  \midrule
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Question text:} Tell us why you chose this response over others. Consider your first message and top-rated response compared to other responses.
# Rate the following statements about the importance of different attributes in your decision.
# I chose this response... }  \\
#  & \cline{1-4}
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 1740 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 7526 \\
#  & \cline{1-4}
#  & values & \multicolumn{3}{p{0.6\textwidth}}{...reflected my values or cultural perspective } \\
#  &  & \multicolumn{2}{r}{mean } & 66.9 \\
#  &  & \multicolumn{2}{r}{std } & 27.2 \\
#  &  & \multicolumn{2}{r}{min } & 1.0 \\
#  &  & \multicolumn{2}{r}{max } & 100.0 \\
#  & \cline{1-4}
#  & fluency & \multicolumn{3}{p{0.6\textwidth}}{...was well-written and coherent } \\
#  &  & \multicolumn{2}{r}{mean } & 82.5 \\
#  &  & \multicolumn{2}{r}{std } & 18.5 \\
#  &  & \multicolumn{2}{r}{min } & 1.0 \\
#  &  & \multicolumn{2}{r}{max } & 100.0 \\
#  & \cline{1-4}
#  & factuality & \multicolumn{3}{p{0.6\textwidth}}{...was factual and informative } \\
#  &  & \multicolumn{2}{r}{mean } & 79.3 \\
#  &  & \multicolumn{2}{r}{std } & 21.0 \\
#  &  & \multicolumn{2}{r}{min } & 1.0 \\
#  &  & \multicolumn{2}{r}{max } & 100.0 \\
#  & \cline{1-4}
#  & safety & \multicolumn{3}{p{0.6\textwidth}}{...was safe and doesn't risk harm to myself and others } \\
#  &  & \multicolumn{2}{r}{mean } & 72.1 \\
#  &  & \multicolumn{2}{r}{std } & 27.8 \\
#  &  & \multicolumn{2}{r}{min } & 1.0 \\
#  &  & \multicolumn{2}{r}{max } & 100.0 \\
#  & \cline{1-4}
#  & diversity & \multicolumn{3}{p{0.6\textwidth}}{...summarised multiple viewpoints or different worldviews } \\
#  &  & \multicolumn{2}{r}{mean } & 66.0 \\
#  &  & \multicolumn{2}{r}{std } & 26.5 \\
#  &  & \multicolumn{2}{r}{min } & 1.0 \\
#  &  & \multicolumn{2}{r}{max } & 100.0 \\
#  & \cline{1-4}
#  & creativity & \multicolumn{3}{p{0.6\textwidth}}{...was creative and inspiring } \\
#  &  & \multicolumn{2}{r}{mean } & 62.1 \\
#  &  & \multicolumn{2}{r}{std } & 27.1 \\
#  &  & \multicolumn{2}{r}{min } & 1.0 \\
#  &  & \multicolumn{2}{r}{max } & 100.0 \\
#  & \cline{1-4}
#  & helpfulness & \multicolumn{3}{p{0.6\textwidth}}{...was helpful and relevant to my request } \\
#  &  & \multicolumn{2}{r}{mean } & 82.5 \\
#  &  & \multicolumn{2}{r}{std } & 20.0 \\
#  &  & \multicolumn{2}{r}{min } & 1.0 \\
#  &  & \multicolumn{2}{r}{max } & 100.0 \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: Sliders from [Very unimportant] to [Very important] are recorded on a 1-100 scale. Participant does not see numeric value.
# Note that the attributes align with performance\_attributes, as well as the stated preference ratings from The Survey.
# Participants had option to select N/A, which is recorded as Null.
# num\_missing indicates the number of participants who have at least one missing value in the nested columns.
# num\_unique indicates the unique combinations of use cases selected by participants.
# There was no option for 'other'.
# Note, these sliders run from 1-100 (on Dynabench). The sliders for stated\_prefs (in Survey on Qualtrics) run 0-100. }}  \\
#  & \cline{1-4}
# \end{longtable}

# %%
style_latex(restructure_data(UTTER_ENTRIES))
# Out:
#      variable_name                                     variable_label  \
# 0          user_id                      Unique participant identifier
# 1  conversation_id                     Unique conversation identifier
# 2   interaction_id  Unique interaction identifier, where an intera...
#
#   variable_category variable_type question_text  num_missing  num_unique  \
# 0              meta     string id             -            0        1396
# 1              meta     string id             -            0        8011
# 2              meta     string id             -            0       27172
#
#        values                                              notes
# 0  {'-': '-'}  Pseudonymized from Prolific worker ID. Used to...
# 1  {'-': '-'}  Used to link utterance data to conversation data.
# 2  {'-': '-'}
#           Tag VARIABLE                          LABEL    CATEGORY       TYPE
# 0  0   HEADER  user_id  Unique participant identifier        meta  string id
# 1     OVERALL                                          N Missing:          0
# \fontsize{6pt}{6pt}\selectfont
# \begin{longtable}{p{0.005\textwidth}p{0.20\textwidth}p{0.40\textwidth}p{0.1\textwidth}p{0.1\textwidth}}
# \toprule
#  & VARIABLE & LABEL & CATEGORY & TYPE \\
# \midrule
# \endfirsthead
# \toprule
#  & VARIABLE & LABEL & CATEGORY & TYPE \\
# \midrule
# \endhead
# \midrule
# \multicolumn{5}{r}{Continued on next page} \\
# \midrule
# \endfoot
# \bottomrule
# \endlastfoot
# \bfseries  & \bfseries MIDRULE & \bfseries  & \bfseries  & \bfseries  \\
# \bfseries 0 & \bfseries user\_id & \bfseries Unique participant identifier & \bfseries {\cellcolor{myred}} meta & \bfseries {\cellcolor{myoat}} string id \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 1396 \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: Pseudonymized from Prolific worker ID. Used to link utterance data to survey data. }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 1 & \bfseries conversation\_id & \bfseries Unique conversation identifier & \bfseries {\cellcolor{myred}} meta & \bfseries {\cellcolor{myoat}} string id \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 8011 \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: Used to link utterance data to conversation data. }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 2 & \bfseries interaction\_id & \bfseries Unique interaction identifier, where an interaction is a turn within a conversation (single human message with multiple model responses) & \bfseries {\cellcolor{myred}} meta & \bfseries {\cellcolor{myoat}} string id \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 27172 \\
#  \midrule
# \bfseries 3 & \bfseries utterance\_id & \bfseries Unique utterance identifier, where an utterance is a single human message - single model response pair & \bfseries {\cellcolor{myred}} meta & \bfseries {\cellcolor{myoat}} string id \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 68371 \\
#  \midrule
# \bfseries 4 & \bfseries within\_turn\_id & \bfseries Within turn identifier of up to four model responses to a single human message & \bfseries {\cellcolor{myred}} meta & \bfseries {\cellcolor{myoat}} string id \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 4 \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: Order is random, not based on score or presentation in interface }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 5 & \bfseries included\_in\_balanced\_subset & \bfseries Indicator if participant's conversations are included in the balanced subset & \bfseries {\cellcolor{mygreen}} constructed & \bfseries {\cellcolor{myoat}} binary \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 2 \\
#  &  & \multicolumn{2}{r}{True } & 57401 \\
#  &  & \multicolumn{2}{r}{False } & 10970 \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: Balanced subset was created to equally sample conversations of three types (unguided, values, controversy).
# We only include participants who have at least one of each conversation type, and then ensure equal numbers of each type are retained.
# See paper for details. }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 6 & \bfseries conversation\_type & \bfseries Type of conversation (from pre-defined categories) & \bfseries {\cellcolor{myyellow}} direct & \bfseries {\cellcolor{myoat}} categorical \\
#  \midrule
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Question text:} Choose what type of conversation you want to have. }  \\
#  & \cline{1-4}
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 3 \\
#  &  & \multicolumn{2}{r}{unguided } & 3113 \\
#  &  & \multicolumn{2}{r}{values guided } & 2460 \\
#  &  & \multicolumn{2}{r}{controversy guided } & 2438 \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: Participants pick from the following radio buttons:
# Unguided. Ask, request or talk to the model about anything . It is up to you!
# Values guided. Ask, request or talk to the model about something important to you or that represents your values . This could be related to work, religion, family and relationship, politics or culture.
# Controversy guided. Ask, request or talk to the model about something controversial or where people would disagree in your community, culture or country.
# We also provide the additional instruction: Remember if you are here as a paid study participant, you need to do two of each type. If you are here as a volunteer, then take your pick!
#  }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 7 & \bfseries turn & \bfseries Turn of conversation when prompt was entered & \bfseries {\cellcolor{myred}} meta & \bfseries {\cellcolor{myoat}} int \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 22 \\
#  &  & \multicolumn{2}{r}{mean } & 1.2 \\
#  &  & \multicolumn{2}{r}{std } & 1.6 \\
#  &  & \multicolumn{2}{r}{min } & 0.0 \\
#  &  & \multicolumn{2}{r}{max } & 21.0 \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: In the paper, we refer to the first turn as T=1. Here, we index the first turn as 0. }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 8 & \bfseries model\_name & \bfseries Name of LLM & \bfseries {\cellcolor{myred}} meta & \bfseries {\cellcolor{myoat}} categorical \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 21 \\
#  &  & \multicolumn{2}{r}{command } & 4812 \\
#  &  & \multicolumn{2}{r}{claude-instant-1 } & 4292 \\
#  &  & \multicolumn{2}{r}{models/chat-bison-001 } & 4168 \\
#  &  & \multicolumn{2}{r}{HuggingFaceH4/zephyr-7b-beta } & 4133 \\
#  &  & \multicolumn{2}{r}{meta-llama/Llama-2-7b-chat-hf } & 3995 \\
#  &  & \multicolumn{2}{r}{command-light } & 3929 \\
#  &  & \multicolumn{2}{r}{command-nightly } & 3816 \\
#  &  & \multicolumn{2}{r}{gpt-4-1106-preview } & 3735 \\
#  &  & \multicolumn{2}{r}{gpt-4 } & 3515 \\
#  &  & \multicolumn{2}{r}{meta-llama/Llama-2-70b-chat-hf } & 3493 \\
#  &  & \multicolumn{2}{r}{gpt-3.5-turbo } & 3471 \\
#  &  & \multicolumn{2}{r}{timdettmers/guanaco-33b-merged } & 3468 \\
#  &  & \multicolumn{2}{r}{claude-2.1 } & 3338 \\
#  &  & \multicolumn{2}{r}{mistralai/Mistral-7B-Instruct-v0.1 } & 3261 \\
#  &  & \multicolumn{2}{r}{claude-2 } & 3209 \\
#  &  & \multicolumn{2}{r}{tiiuae/falcon-7b-instruct } & 2608 \\
#  &  & \multicolumn{2}{r}{OpenAssistant/oasst-sft-4-pythia-12b-epoch-3.5 } & 2314 \\
#  &  & \multicolumn{2}{r}{meta-llama/Llama-2-13b-chat-hf } & 1744 \\
#  &  & \multicolumn{2}{r}{luminous-supreme-control } & 1722 \\
#  &  & \multicolumn{2}{r}{google/flan-t5-xxl } & 1715 \\
#  &  & \multicolumn{2}{r}{luminous-extended-control } & 1633 \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: We provide the long name as it appeared on our backend.
# We provide a mapping of long names to shorter more familiar names on our Github or in the paper. }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 9 & \bfseries model\_provider & \bfseries Provider of the LLM & \bfseries {\cellcolor{myred}} meta & \bfseries {\cellcolor{myoat}} categorical \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 6 \\
#  &  & \multicolumn{2}{r}{huggingface\_api } & 26731 \\
#  &  & \multicolumn{2}{r}{cohere } & 12557 \\
#  &  & \multicolumn{2}{r}{anthropic } & 10839 \\
#  &  & \multicolumn{2}{r}{openai } & 10721 \\
#  &  & \multicolumn{2}{r}{google } & 4168 \\
#  &  & \multicolumn{2}{r}{aleph } & 3355 \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: Note for open-access LLMs, HuggingFace API is always listed as the source and does not imply they built the model. }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 10 & \bfseries user\_prompt & \bfseries Human-written message. & \bfseries {\cellcolor{myyellow}} direct & \bfseries {\cellcolor{myoat}} string \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 26673 \\
#  &  & \multicolumn{2}{r}{mean chars } & 69.9 \\
#  &  & \multicolumn{2}{r}{std chars } & 62.0 \\
#  &  & \multicolumn{2}{r}{min chars } & 1.0 \\
#  &  & \multicolumn{2}{r}{max chars } & 1311.0 \\
#  \midrule
# \bfseries 11 & \bfseries model\_response & \bfseries Model-generated response & \bfseries {\cellcolor{myyellow}} direct & \bfseries {\cellcolor{myoat}} string \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 66614 \\
#  &  & \multicolumn{2}{r}{mean chars } & 565.3 \\
#  &  & \multicolumn{2}{r}{std chars } & 387.9 \\
#  &  & \multicolumn{2}{r}{min chars } & 1.0 \\
#  &  & \multicolumn{2}{r}{max chars } & 4630.0 \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: An empty string is stored as `EMPTY STRING'. }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 12 & \bfseries score & \bfseries Score of the model response & \bfseries {\cellcolor{myyellow}} direct & \bfseries {\cellcolor{myoat}} int \\
#  \midrule
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Question text:} Rate the model responses. There are no right or wrong answers. Use your subjective judgement. }  \\
#  & \cline{1-4}
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 100 \\
#  &  & \multicolumn{2}{r}{mean } & 65.1 \\
#  &  & \multicolumn{2}{r}{std } & 29.3 \\
#  &  & \multicolumn{2}{r}{min } & 1.0 \\
#  &  & \multicolumn{2}{r}{max } & 100.0 \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: Sliders from [Terrible] to [Perfect] are recorded on a 1-100 scale. Participant does not see numeric value. }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 13 & \bfseries if\_chosen & \bfseries Whether model response was highest-rated by participant & \bfseries {\cellcolor{mygreen}} constructed & \bfseries {\cellcolor{myoat}} binary \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 2 \\
#  &  & \multicolumn{2}{r}{False } & 40934 \\
#  &  & \multicolumn{2}{r}{True } & 27437 \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: In case of a tie, a random response is chosen. }}  \\
#  & \cline{1-4}
# \end{longtable}

# %%
style_latex(restructure_data(META_ENTRIES))
# Out:
#      variable_name                  variable_label variable_category  \
# 0        column_id        Source of text utterance              meta
# 1          user_id   Unique participant identifier              meta
# 2  conversation_id  Unique conversation identifier              meta
#
#   variable_type question_text num_missing num_unique  \
# 0   categorical             -           0          5
# 1     string id             -           0       1500
# 2     string id             -        3000       8011
#
#                                               values  \
# 0  {'model_response': 68371, 'user_prompt': 27172...
# 1                                         {'-': '-'}
# 2                                         {'-': '-'}
#
#                                                notes
# 0
# 1  Pseudonymized from Prolific worker ID. Used to...
# 2                Used to link metadata to main data.
#           Tag   VARIABLE                     LABEL    CATEGORY         TYPE
# 0  0   HEADER  column_id  Source of text utterance        meta  categorical
# 1     OVERALL                                       N Missing:            0
# \fontsize{6pt}{6pt}\selectfont
# \begin{longtable}{p{0.005\textwidth}p{0.20\textwidth}p{0.40\textwidth}p{0.1\textwidth}p{0.1\textwidth}}
# \toprule
#  & VARIABLE & LABEL & CATEGORY & TYPE \\
# \midrule
# \endfirsthead
# \toprule
#  & VARIABLE & LABEL & CATEGORY & TYPE \\
# \midrule
# \endhead
# \midrule
# \multicolumn{5}{r}{Continued on next page} \\
# \midrule
# \endfoot
# \bottomrule
# \endlastfoot
# \bfseries  & \bfseries MIDRULE & \bfseries  & \bfseries  & \bfseries  \\
# \bfseries 0 & \bfseries column\_id & \bfseries Source of text utterance & \bfseries {\cellcolor{myred}} meta & \bfseries {\cellcolor{myoat}} categorical \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 5 \\
#  &  & \multicolumn{2}{r}{model\_response } & 68371 \\
#  &  & \multicolumn{2}{r}{user\_prompt } & 27172 \\
#  &  & \multicolumn{2}{r}{open\_feedback } & 8011 \\
#  &  & \multicolumn{2}{r}{self\_description } & 1500 \\
#  &  & \multicolumn{2}{r}{system\_string } & 1500 \\
#  \midrule
# \bfseries 1 & \bfseries user\_id & \bfseries Unique participant identifier & \bfseries {\cellcolor{myred}} meta & \bfseries {\cellcolor{myoat}} string id \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 1500 \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: Pseudonymized from Prolific worker ID. Used to link metadata to main data. }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 2 & \bfseries conversation\_id & \bfseries Unique conversation identifier & \bfseries {\cellcolor{myred}} meta & \bfseries {\cellcolor{myoat}} string id \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 3000 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 8011 \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: Used to link metadata to main data. }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 3 & \bfseries interaction\_id & \bfseries Unique interaction identifier, where an interaction is a turn within a conversation (single human message with multiple model responses) & \bfseries {\cellcolor{myred}} meta & \bfseries {\cellcolor{myoat}} string id \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 11011 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 27172 \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: Used to link metadata to main data. }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 4 & \bfseries utterance\_id & \bfseries Unique utterance identifier, where an utterance is a single human message - single model response pair & \bfseries {\cellcolor{myred}} meta & \bfseries {\cellcolor{myoat}} string id \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 38183 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 68371 \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: Used to link metadata to main data. }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 5 & \bfseries pii\_flag & \bfseries Automated flag for personally identifiable information & \bfseries {\cellcolor{myred}} meta & \bfseries {\cellcolor{myoat}} binary \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 2 \\
#  &  & \multicolumn{2}{r}{False } & 105443 \\
#  &  & \multicolumn{2}{r}{True } & 1111 \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: Uses scrubadub https://scrubadub.readthedocs.io/en/stable/ to find PII. There may be some misclassifications.
# Many of the inspected positives were false positives. All positive human-written texts checked.
# See pii\_manual\_flag. }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 6 & \bfseries pii\_manual\_flag & \bfseries Manual verification of personally identifiable information in human-written texts & \bfseries {\cellcolor{myred}} meta & \bfseries {\cellcolor{myoat}} binary \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 106387 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 1 \\
#  &  & \multicolumn{2}{r}{nan } & 106387 \\
#  &  & \multicolumn{2}{r}{0.0 } & 167 \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: For any automated PII flags, we manually checked the human-written text for PII.
# All were false positives so this flag overules the automated flag. We did not check model-generated text for PII.
# NaN indicates entry was not manually checked. }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 7 & \bfseries language\_flag & \bfseries Automated language detection & \bfseries {\cellcolor{myred}} meta & \bfseries {\cellcolor{myoat}} categorical \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 59 \\
#  &  & \multicolumn{2}{r}{Too many values to show } & - \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: Uses langid. There may be some misclassifications. }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 8 & \bfseries en\_flag & \bfseries Whether detected language is English & \bfseries {\cellcolor{myred}} meta & \bfseries {\cellcolor{myoat}} binary \\
#  \midrule
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Missing: & \bfseries 0 \\
# \bfseries  & \bfseries  & \bfseries  & \bfseries N Unique: & \bfseries 2 \\
#  &  & \multicolumn{2}{r}{Too many values to show } & - \\
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: Constructed based on automated language detection. }}  \\
#  & \cline{1-4}
#  \midrule
# \bfseries 9 & \bfseries moderation\_flag & \bfseries Automated flag for moderation & \bfseries {\cellcolor{myred}} meta & \bfseries nested dict \\
#  \midrule
#  & \multicolumn{4}{p{0.9\textwidth}}{\textit{Notes: Uses OpenAI moderation API. There may be some misclassifications.
# Nested dictionary with binary flags and probabilities for sub-categories of harm. }}  \\
#  & \cline{1-4}
# \end{longtable}
